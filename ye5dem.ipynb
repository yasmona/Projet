# %%
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.models import Sequential
from keras.layers import LSTM,Dense,Input,ConvLSTM2D,Reshape,Activation,Lambda,Softmax,Concatenate
from keras.layers import Dense, LSTM, Input, Embedding, TimeDistributed, Flatten, Dropout,RepeatVector,Reshape,Activation,Lambda,Softmax
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import numpy as np
from sklearn.model_selection import train_test_split
import re
import pandas as pd
from keras import backend as K
import keras.backend as kerback
#from keras.models import Model
from tensorflow.keras.models import Model
from keras.preprocessing.text import one_hot
import tensorflow as tf
from keras.optimizers import Adam

# %%
# train a generative adversarial network on a one-dimensional function
from numpy import hstack
from numpy import zeros
from numpy import ones
from numpy import random
from numpy.random import rand
from numpy.random import randn
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import UpSampling2D, Reshape, Activation, Conv2D, BatchNormalization, LeakyReLU, Input, Flatten, multiply,Conv2DTranspose
from keras.layers import Dense, Embedding
from keras.models import Sequential, Model

# %%
#classe:data_load
def nettoyer_data(f):
    data = pd.read_csv(f, sep="\n",header=None)
    list_listword=[]#liste des listes des mots de chaque tweet
    list_tweets=data[0].values.tolist()#liste des tweets
    l=[]
    for text in list_tweets:
        text = re.sub(r'http\S+', '', text)   # Remove URLs
        text = re.sub(r'—', ' ', text) 
        text = re.sub(r'@[a-zA-Z0-9_]+', '', text)  # Remove @ mentions
        text = text.strip(" ")   # Remove whitespace resulting from above
        text = re.sub(r' +', ' ', text)   # Remove redundant spaces
        l.append(text)
    
    return l

# %%
list_tweets=nettoyer_data('C:/tweet.txt')

# %%
#classe:data_load
def tokenizer_data(list_tweets):
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(list_tweets)
    sequences = tokenizer.texts_to_sequences(list_tweets)
    vocab_size=len(tokenizer.word_index)
    return sequences, vocab_size

def max_tweet(sequences):
    max_length=0
    for i in range(len(sequences)):
        if(len(sequences[i])>max_length):
            max_length=len(sequences[i])
    return max_length

sequences,vocab_size=tokenizer_data(list_tweets)
max_length=max_tweet(sequences)
sequences=np.array([xi+[0]*(max_length-len(xi)) for xi in sequences])
y=sequences[:,-1]
print(y.shape)
y_train = y.reshape(-1, 1)
X=sequences
X_train = np.expand_dims(X, axis=2)
nb_tweet=len(sequences)
batch_size=max_length
print(vocab_size)
# Out:
# (66,)
# 841

# %%
import keras.backend as kerback
#classe :generateur
# define the standalone generator model
def build_generator(n_outputs):#max_length nombre d'element das une tweet
   
    noise=Input(shape=(57,1))
    print(noise.shape)
    label=Input(shape=(57,1))
    print(label.shape)
    #label_emb=Embedding(vocab_size,1)(label)
    
    x0=Concatenate(axis=2)([noise,label])
    x1=LSTM(15, activation='relu',input_dim=n_outputs)(x0)
    #15 nombre de neurone ,batch_size=n_batch=20 
    # repeat vector
    x2=RepeatVector(n_outputs)(x1)
    # decoder layer
    x3=LSTM(15, activation='relu', return_sequences=True)(x2)
    x4=TimeDistributed(Dense(1))(x3)
    unstacked = Lambda(lambda x: tf.unstack(x, axis=2))(x4)
    dense_outputs = [Dense(n_outputs)(x) for x in unstacked]
    merged = Lambda(lambda x: K.stack(x, axis=2))(dense_outputs)

    #generated_tweet=model(x0)
    model = Model([noise,label],merged)
    model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])
    print('generator')
    print(model.summary())
    return  model

build_generator(57)
# Out:
# (None, 57, 1)
# (None, 57, 1)
# generator
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 57, 1)]      0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 57, 1)]      0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 57, 2)        0           input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     (None, 15)           1080        concatenate[0][0]
# __________________________________________________________________________________________________
# repeat_vector (RepeatVector)    (None, 57, 15)       0           lstm[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 57, 15)       1860        repeat_vector[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, 57, 1)        16          lstm_1[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 [(None, 57)]         0           time_distributed[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 57)           3306        lambda[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 57, 1)        0           dense_1[0][0]
# ==================================================================================================
# Total params: 6,262
# Trainable params: 6,262
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
#classe: discriminateur
# define the standalone discriminator model
def build_discriminator(n_inputs):
    tweet=Input(shape=(n_inputs,1)) #n_imput nombre des element 
    
    label=Input(shape=(n_inputs,1))
    #label_emb=Embedding(vocab_size,1)(label)
    
    x0=Concatenate(axis=1)([tweet,label])
    x2=LSTM(15, activation='relu', input_dim=n_inputs)(x0)
    x3=RepeatVector(n_inputs)(x2)
    x4=LSTM(15, activation='relu', return_sequences=True)(x3)
    x5=TimeDistributed(Dense(1))(x4)
    unstacked = Lambda(lambda x: tf.unstack(x, axis=2))(x5)
    dense_outputs = [Dense(n_inputs)(x) for x in unstacked]
    merged = Lambda(lambda x: K.stack(x, axis=2))(dense_outputs)
    x1=Flatten()(merged)
    x6=Dense(1, activation='sigmoid')(x1)
    model = Model([tweet,label], x6)
    print(model.summary())
    model.compile(optimizer='adam', loss='binary_crossentropy' ,metrics=['accuracy'])
    return model
build_discriminator(57)
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 57, 1)]      0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 57, 1)]      0
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 114, 1)       0           input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 15)           1020        concatenate_1[0][0]
# __________________________________________________________________________________________________
# repeat_vector_1 (RepeatVector)  (None, 57, 15)       0           lstm_2[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 57, 15)       1860        repeat_vector_1[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 57, 1)        16          lstm_3[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               [(None, 57)]         0           time_distributed_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 57)           3306        lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 57, 1)        0           dense_3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 57)           0           lambda_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            58          flatten[0][0]
# ==================================================================================================
# Total params: 6,260
# Trainable params: 6,260
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
#classe:GAN
# define the combined generator and discriminator model
def build_gan(generator, discriminator):
    # make weights in the discriminator not trainable
    discriminator.trainable = False
    # connect them
    model = Sequential()
    # add generator
    #model.add(generator)
    x0=Input(shape=(57,1))
    x1=Input(shape=(57,))
    x2=generator([x0,x1])
    print(x2[-1].shape)
    x3=discriminator([x2,x1])
    print(x3.shape)
    model = Model([x0,x1], x3)
    # add the discriminator
    #model.add(discriminator)
    # compile model
    model.compile(loss='binary_crossentropy', optimizer='adam',metrics=['accuracy'])
    print(model.summary())
    return model
define_gan(build_generator(57), build_discriminator(57))
# Out:
# (None, 57, 1)
# (None, 57, 1)
# generator
# Model: "functional_17"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_17 (InputLayer)           [(None, 57, 1)]      0
# __________________________________________________________________________________________________
# input_18 (InputLayer)           [(None, 57, 1)]      0
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 57, 2)        0           input_17[0][0]
#                                                                  input_18[0][0]
# __________________________________________________________________________________________________
# lstm_12 (LSTM)                  (None, 15)           1080        concatenate_6[0][0]
# __________________________________________________________________________________________________
# repeat_vector_6 (RepeatVector)  (None, 57, 15)       0           lstm_12[0][0]
# __________________________________________________________________________________________________
# lstm_13 (LSTM)                  (None, 57, 15)       1860        repeat_vector_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_6 (TimeDistrib (None, 57, 1)        16          lstm_13[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              [(None, 57)]         0           time_distributed_6[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 57)           3306        lambda_12[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 57, 1)        0           dense_16[0][0]
# ==================================================================================================
# Total params: 6,262
# Trainable params: 6,262
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Model: "functional_19"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_19 (InputLayer)           [(None, 57, 1)]      0
# __________________________________________________________________________________________________
# input_20 (InputLayer)           [(None, 57, 1)]      0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 114, 1)       0           input_19[0][0]
#                                                                  input_20[0][0]
# __________________________________________________________________________________________________
# lstm_14 (LSTM)                  (None, 15)           1020        concatenate_7[0][0]
# __________________________________________________________________________________________________
# repeat_vector_7 (RepeatVector)  (None, 57, 15)       0           lstm_14[0][0]
# __________________________________________________________________________________________________
# lstm_15 (LSTM)                  (None, 57, 15)       1860        repeat_vector_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (None, 57, 1)        16          lstm_15[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              [(None, 57)]         0           time_distributed_7[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 57)           3306        lambda_14[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 57, 1)        0           dense_18[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 57)           0           lambda_15[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 1)            58          flatten_3[0][0]
# ==================================================================================================
# Total params: 6,260
# Trainable params: 6,260
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# (57, 1)
# (None, 1)
# Model: "functional_21"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_21 (InputLayer)           [(None, 57, 1)]      0
# __________________________________________________________________________________________________
# input_22 (InputLayer)           [(None, 57)]         0
# __________________________________________________________________________________________________
# functional_17 (Functional)      (None, 57, 1)        6262        input_21[0][0]
#                                                                  input_22[0][0]
# __________________________________________________________________________________________________
# functional_19 (Functional)      (None, 1)            6260        functional_17[0][0]
#                                                                  input_22[0][0]
# ==================================================================================================
# Total params: 12,522
# Trainable params: 6,262
# Non-trainable params: 6,260
# __________________________________________________________________________________________________
# None

# %%
#classe:GAN
generator = build_generator(max_length)
# Build and compile the discriminator
discriminator = build_discriminator(max_length)
#discriminator.compile(optimizer='adam', loss='binary_crossentropy' ,metrics=['accuracy'])

# Build and compile the combined model
gan_model = define_gan(generator, discriminator)
# Out:
# (None, 57, 1)
# (None, 57, 1)
# generator
# Model: "functional_23"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_23 (InputLayer)           [(None, 57, 1)]      0
# __________________________________________________________________________________________________
# input_24 (InputLayer)           [(None, 57, 1)]      0
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 57, 2)        0           input_23[0][0]
#                                                                  input_24[0][0]
# __________________________________________________________________________________________________
# lstm_16 (LSTM)                  (None, 15)           1080        concatenate_8[0][0]
# __________________________________________________________________________________________________
# repeat_vector_8 (RepeatVector)  (None, 57, 15)       0           lstm_16[0][0]
# __________________________________________________________________________________________________
# lstm_17 (LSTM)                  (None, 57, 15)       1860        repeat_vector_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_8 (TimeDistrib (None, 57, 1)        16          lstm_17[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              [(None, 57)]         0           time_distributed_8[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 57)           3306        lambda_16[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 57, 1)        0           dense_21[0][0]
# ==================================================================================================
# Total params: 6,262
# Trainable params: 6,262
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Model: "functional_25"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_25 (InputLayer)           [(None, 57, 1)]      0
# __________________________________________________________________________________________________
# input_26 (InputLayer)           [(None, 57, 1)]      0
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 114, 1)       0           input_25[0][0]
#                                                                  input_26[0][0]
# __________________________________________________________________________________________________
# lstm_18 (LSTM)                  (None, 15)           1020        concatenate_9[0][0]
# __________________________________________________________________________________________________
# repeat_vector_9 (RepeatVector)  (None, 57, 15)       0           lstm_18[0][0]
# __________________________________________________________________________________________________
# lstm_19 (LSTM)                  (None, 57, 15)       1860        repeat_vector_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_9 (TimeDistrib (None, 57, 1)        16          lstm_19[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              [(None, 57)]         0           time_distributed_9[0][0]
# __________________________________________________________________________________________________
# dense_23 (Dense)                (None, 57)           3306        lambda_18[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 57, 1)        0           dense_23[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 57)           0           lambda_19[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 1)            58          flatten_4[0][0]
# ==================================================================================================
# Total params: 6,260
# Trainable params: 6,260
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# (57, 1)
# (None, 1)
# Model: "functional_27"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_27 (InputLayer)           [(None, 57, 1)]      0
# __________________________________________________________________________________________________
# input_28 (InputLayer)           [(None, 57)]         0
# __________________________________________________________________________________________________
# functional_23 (Functional)      (None, 57, 1)        6262        input_27[0][0]
#                                                                  input_28[0][0]
# __________________________________________________________________________________________________
# functional_25 (Functional)      (None, 1)            6260        functional_23[0][0]
#                                                                  input_28[0][0]
# ==================================================================================================
# Total params: 12,522
# Trainable params: 6,262
# Non-trainable params: 6,260
# __________________________________________________________________________________________________
# None

# %%
#classe: GAN
def generer_tweet(epoch,noise,sampled_labels,g_model):
    result = g_model.predict([noise,sampled_labels])
    print(result)
    #print(result.shape)
    #print(len(result))
    res=[]
    predicted_word =""
    for j in range(57):
        #predicted_word = ''
        for word, index in tokenizer.word_index.items():
            if index == abs(int(result[0][j])):
                predicted_word = predicted_word+' '+word
                break
    res.append(predicted_word)
    print(epoch,res)
    
    #for i in res:
    #    print(i)
    return res

# %%
def disc_text(model_disc, seed_text):
    #print(seed_text)
    sequences, tokenizer=tokenizer_data(seed_text)
    sequences= pad_sequences(sequences, maxlen=max_length, padding='post')
    y = model_disc.predict(sequences)
    #print(y)
    #for i in y:
    if(i<0.7):
        print("fake")
    else:
        print("real")

# %%
preparer_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-ba2fc8a129f3> in <module>
# ----> 1 preparer_data()
#
# NameError: name 'preparer_data' is not defined

# %%
#GAN
# Store the losses
d_losses = []
g_losses = []
sample_period = 100 # every `sample_period` steps generate and save some data"
Epoch=100
#x_real= generate_real_samples()
X =sequences[:33]
X = pad_sequences(X, maxlen=max_length, padding='post')
#print("X=",X)
y =sequences[33:]
y = pad_sequences(y, maxlen=max_length, padding='post')
#print("y=",y)
X_train=X.reshape(33, max_length, 1)
y_train=y.reshape(33, max_length, 1)
#y_train = y.reshape(-1, 1)
#print(X_train.shape)
#print(y_train.shape)
#X_train = np.expand_dims(X_train, axis=3)
#y_train = np.expand_dims(y_train, axis=3)
real = np.ones(shape=(33, 1))
fake = np.zeros(shape=(33, 1))
noise_fixe = np.random.randint(vocab_size, size=(33, 57,1))
noise_fixe1 = np.random.randint(vocab_size, size=(1, 57,1))
######################## Main training loop###########################
for i in range(Epoch):
        ########################
        ###Train Discriminator##
        #######################
        # prepare real samples
        [tweets, labels]= X_train,y_train
        #print(X_train.shape)
        #idx = np.random.randint(0, X_train.shape[0], batch_size)
        #print(idx.shape)
        
        #tweets, labels = X_train[idx], y_train[idx]
        #print(tweets.shape)
        #print(labels.shape)
        #print(labels)
        # Sample noise as generator input
        lab=labels[-1].reshape(1,57, 1)
        noise = np.random.randint(vocab_size, size=(33, 57,1))
        #print(noise.shape)
        # Generate fake tweets
        gen_twt= generator.predict([noise,labels])
        f=fake[-1].reshape(1, 1)
                # Train the discriminator
        # both loss and accuracy are returned
        d_loss_real, d_acc_real=discriminator.train_on_batch([tweets,labels], real)
        d_loss_fake, d_acc_fake =discriminator.train_on_batch([gen_twt,labels], fake)
        d_loss = 0.5 * (d_loss_real + d_loss_fake)
        d_acc  = 0.5 * (d_acc_real + d_acc_fake)
        
        #######################
        ### Train generator ###
        #######################
    
        # Condition on labels
        sampled_labels = np.random.randint(0, 10, batch_size)                          
        #print(labels.shape) 
        #noise = np.random.randint(vocab_size, size=(33, 57,1))
        y_gan = ones((33, 1))
        #print(y_gan.shape)
        lab=labels[random.randint(0, 33)].reshape(1,57, 1)
        # update the generator via the discriminator's error
        #noise=random.randn(57,1)
        #gan_model([noise,x_real[-1]], y_gan).summary()
        g_loss=gan_model.train_on_batch([noise_fixe,labels], y_gan)
        #noise = np.random.randint(vocab_size, size=(1, 57,1))
        # Save the losses
        d_losses.append(d_loss)
        g_losses.append(g_loss)
        
        #if i % 2 == 100:#after 100 epoch we save
        #if i % sample_period == 0:
        #print(f"epoch: {i+1}, d_loss: {d_loss:.2f}, \d_acc: {d_acc:.2f}, g_loss: {g_loss:.2f}")
        print("d_loss",d_loss)
        print("d_acc:",d_acc)
        print("g_loss",g_loss)
        print(noise_fixe1.shape)
        print(lab.shape)
        generer_tweet(i,noise_fixe1,lab, generator)
        #disc_text(discriminator, tex)
# Out:
# d_loss 0.6962137222290039
# d_acc: 0.5
# g_loss [0.7008492946624756, 0.7272727489471436]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 160.32996 ]
#   [-226.86769 ]
#   [-313.11697 ]
#   [-400.55273 ]
#   [ 850.3242  ]
#   [-167.54459 ]
#   [ 611.953   ]
#   [-212.32814 ]
#   [ 386.45288 ]
#   [ 556.0167  ]
#   [  40.83582 ]
#   [-121.03797 ]
#   [ 360.80447 ]
#   [ 292.76056 ]
#   [ 118.48973 ]
#   [-117.12055 ]
#   [ 460.60474 ]
#   [ 175.37033 ]
#   [ -93.92264 ]
#   [ 125.201294]
#   [ 243.65448 ]
#   [-261.04593 ]
#   [ 668.5235  ]
#   [ 596.0092  ]
#   [ 839.5925  ]
#   [ 421.9698  ]
#   [ -11.522808]
#   [-686.7479  ]
#   [ 355.1069  ]
#   [-261.10413 ]
#   [-154.75627 ]
#   [ 429.7524  ]
#   [ -41.773582]
#   [-363.87628 ]
#   [ 391.94794 ]
#   [ 905.8011  ]
#   [ 490.9611  ]
#   [ 151.19458 ]
#   [ 557.8558  ]
#   [ -57.68177 ]
#   [ -61.74944 ]
#   [ -28.727762]
#   [ 902.04285 ]
#   [ 162.84697 ]
#   [-340.8428  ]
#   [ -10.160536]
#   [ 132.07126 ]
#   [-136.76758 ]
#   [ 306.41675 ]
#   [ 146.3688  ]
#   [-128.58788 ]
#   [-376.7551  ]
#   [ 138.97023 ]
#   [ 542.41614 ]
#   [-189.31242 ]
#   [ 482.03342 ]
#   [-774.35034 ]]]
# 0 [' way very veterans aimed again playlist available side healthcare out best narrative stuck had off luther hotline folks friend made senate reached thanksgiving heroes accomplish for plans provoked senate center strongest get truth wanted 7 going inside early his at build volunteer it days than decided during person officially promised moratorium week beloved looking']
# d_loss 0.6858528256416321
# d_acc: 0.4848484992980957
# g_loss [0.7371084094047546, 0.6969696879386902]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 176.68567 ]
#   [-248.72107 ]
#   [-341.75275 ]
#   [-439.2005  ]
#   [ 931.3373  ]
#   [-184.35596 ]
#   [ 669.6413  ]
#   [-233.5436  ]
#   [ 423.35358 ]
#   [ 608.87787 ]
#   [  45.360905]
#   [-132.08844 ]
#   [ 395.68747 ]
#   [ 320.16727 ]
#   [ 130.2716  ]
#   [-128.1664  ]
#   [ 503.6997  ]
#   [ 192.59273 ]
#   [-102.7619  ]
#   [ 136.74998 ]
#   [ 266.99426 ]
#   [-286.0435  ]
#   [ 731.8048  ]
#   [ 652.04407 ]
#   [ 919.09503 ]
#   [ 461.83362 ]
#   [ -12.779666]
#   [-752.08777 ]
#   [ 389.00256 ]
#   [-285.98163 ]
#   [-169.26416 ]
#   [ 469.91455 ]
#   [ -45.180756]
#   [-397.75348 ]
#   [ 428.92288 ]
#   [ 990.99695 ]
#   [ 537.46387 ]
#   [ 165.13786 ]
#   [ 610.85114 ]
#   [ -63.26736 ]
#   [ -67.51898 ]
#   [ -30.745314]
#   [ 987.004   ]
#   [ 178.3589  ]
#   [-373.63397 ]
#   [ -11.730281]
#   [ 144.33821 ]
#   [-149.83627 ]
#   [ 335.80124 ]
#   [ 159.91826 ]
#   [-140.81357 ]
#   [-412.37924 ]
#   [ 152.4583  ]
#   [ 593.6414  ]
#   [-207.24269 ]
#   [ 528.0143  ]
#   [-847.4629  ]]]
# 1 [' 1 congratulations worker rejoining even shores birthday unlike fred be days club kamala americans person individual important things than far can’t quarterback turn king is beings bookstores start poll tests be spiked players holidays u songs before an from bring challenge for these were there’s book got cicely stay actions middle spend']
# d_loss 0.6856056749820709
# d_acc: 0.4848484992980957
# g_loss [0.6881152391433716, 0.8787878751754761]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 100.8727   ]
#   [-145.3381   ]
#   [-200.272    ]
#   [-255.02287  ]
#   [ 540.6734   ]
#   [-106.5542   ]
#   [ 390.1951   ]
#   [-135.71858  ]
#   [ 247.07417  ]
#   [ 353.17163  ]
#   [  26.996153 ]
#   [ -77.278854 ]
#   [ 228.9551   ]
#   [ 186.97597  ]
#   [  74.248055 ]
#   [ -74.397766 ]
#   [ 293.45074  ]
#   [ 109.74298  ]
#   [ -59.43518  ]
#   [  79.83242  ]
#   [ 155.09006  ]
#   [-166.12209  ]
#   [ 425.51242  ]
#   [ 379.66452  ]
#   [ 533.7555   ]
#   [ 268.93887  ]
#   [  -7.138376 ]
#   [-435.8253   ]
#   [ 225.59283  ]
#   [-165.6231   ]
#   [ -99.07177  ]
#   [ 274.90033  ]
#   [ -27.92949  ]
#   [-232.87778  ]
#   [ 250.01823  ]
#   [ 577.75433  ]
#   [ 312.2665   ]
#   [  97.26334  ]
#   [ 354.523    ]
#   [ -36.874237 ]
#   [ -39.26364  ]
#   [ -19.650345 ]
#   [ 574.9347   ]
#   [ 103.929184 ]
#   [-215.42018  ]
#   [  -5.5364056]
#   [  84.53294  ]
#   [ -86.8097   ]
#   [ 194.29703  ]
#   [  93.67287  ]
#   [ -82.13696  ]
#   [-239.92615  ]
#   [  87.27907  ]
#   [ 345.69952  ]
#   [-120.29182  ]
#   [ 305.619    ]
#   [-493.13983  ]]]
# 2 [" help health big takes extending michelle play next everything charles election family jackie what's me me between new change now 2021 s mark breathe merry respond our man surprise u you're away country others gave clarified determination who alston us are make hanukkah they isn’t in better care presidency folks some biden there changing ever came either"]
# d_loss 0.6785536110401154
# d_acc: 0.560606062412262
# g_loss [0.673578679561615, 0.6363636255264282]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 0.01465223]
#   [-0.06866074]
#   [-0.10641857]
#   [-0.14851514]
#   [ 0.2688897 ]
#   [-0.04072528]
#   [ 0.21992369]
#   [-0.05404124]
#   [ 0.13404411]
#   [ 0.20689566]
#   [ 0.0468744 ]
#   [-0.02578835]
#   [ 0.13941899]
#   [ 0.13297284]
#   [ 0.08933906]
#   [-0.05593935]
#   [ 0.14332537]
#   [ 0.08712616]
#   [-0.01071167]
#   [ 0.0279569 ]
#   [ 0.08557487]
#   [-0.06891789]
#   [ 0.25839266]
#   [ 0.19921857]
#   [ 0.28000233]
#   [ 0.15591192]
#   [ 0.01010917]
#   [-0.20575751]
#   [ 0.1172967 ]
#   [-0.10537042]
#   [-0.04023326]
#   [ 0.17794785]
#   [-0.01123964]
#   [-0.07495424]
#   [ 0.14487702]
#   [ 0.3262863 ]
#   [ 0.18500456]
#   [ 0.07320065]
#   [ 0.20699026]
#   [-0.03943566]
#   [-0.0234394 ]
#   [ 0.00661891]
#   [ 0.3094829 ]
#   [ 0.05683976]
#   [-0.09054982]
#   [-0.0180576 ]
#   [ 0.03020196]
#   [-0.0648985 ]
#   [ 0.11992347]
#   [ 0.02703882]
#   [-0.08152939]
#   [-0.18130925]
#   [ 0.04197766]
#   [ 0.1968508 ]
#   [-0.09587248]
#   [ 0.13031843]
#   [-0.2733997 ]]]
# 3 ['']
# d_loss 0.7141345143318176
# d_acc: 0.5454545617103577
# g_loss [0.6759750247001648, 0.4848484992980957]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 161.02913 ]
#   [-226.36911 ]
#   [-308.37808 ]
#   [-398.52838 ]
#   [ 843.2467  ]
#   [-168.08708 ]
#   [ 606.00946 ]
#   [-213.15363 ]
#   [ 384.41455 ]
#   [ 550.5112  ]
#   [  42.62466 ]
#   [-118.93987 ]
#   [ 358.50876 ]
#   [ 289.74164 ]
#   [ 117.87635 ]
#   [-115.77128 ]
#   [ 455.43076 ]
#   [ 173.629   ]
#   [ -92.91179 ]
#   [ 123.580444]
#   [ 241.68861 ]
#   [-259.126   ]
#   [ 661.79785 ]
#   [ 589.7655  ]
#   [ 831.0458  ]
#   [ 417.7312  ]
#   [ -11.6667  ]
#   [-680.01904 ]
#   [ 351.9222  ]
#   [-258.76028 ]
#   [-153.14682 ]
#   [ 425.02472 ]
#   [ -41.029377]
#   [-359.9094  ]
#   [ 388.08777 ]
#   [ 896.6398  ]
#   [ 485.97525 ]
#   [ 149.49394 ]
#   [ 552.6592  ]
#   [ -57.37011 ]
#   [ -61.102844]
#   [ -27.712252]
#   [ 892.8781  ]
#   [ 161.49876 ]
#   [-337.81473 ]
#   [ -10.614951]
#   [ 130.53503 ]
#   [-135.68306 ]
#   [ 303.79865 ]
#   [ 144.46118 ]
#   [-127.4336  ]
#   [-372.8791  ]
#   [ 137.61269 ]
#   [ 536.97864 ]
#   [-187.48462 ]
#   [ 477.47952 ]
#   [-766.4744  ]]]
# 4 [' honor very you’ll cleats four fun real growth until day had assumptions distancing off down whether call i’m everyone once 5816 monica decisions helping actors for future alma 730 difference mark get define independent forward were socially early his country honor want it americans next mask these voter urgency lives worried still miche 365']
# d_loss 0.6812834739685059
# d_acc: 0.530303031206131
# g_loss [0.6747090220451355, 0.5151515007019043]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 0.00905999]
#   [-0.04826896]
#   [-0.06925873]
#   [-0.09801847]
#   [ 0.18301487]
#   [-0.02516516]
#   [ 0.15415427]
#   [-0.03434889]
#   [ 0.09554769]
#   [ 0.1450529 ]
#   [ 0.03505877]
#   [-0.01477975]
#   [ 0.099478  ]
#   [ 0.09486172]
#   [ 0.06482661]
#   [-0.03565647]
#   [ 0.1026338 ]
#   [ 0.061774  ]
#   [-0.00417665]
#   [ 0.02112343]
#   [ 0.05987413]
#   [-0.04466537]
#   [ 0.17988455]
#   [ 0.13842759]
#   [ 0.19391467]
#   [ 0.10828737]
#   [ 0.01140397]
#   [-0.13792574]
#   [ 0.07965108]
#   [-0.07138259]
#   [-0.02140313]
#   [ 0.12474769]
#   [-0.01135879]
#   [-0.04626519]
#   [ 0.10621867]
#   [ 0.22706535]
#   [ 0.13021576]
#   [ 0.04867632]
#   [ 0.14378549]
#   [-0.02548472]
#   [-0.01820024]
#   [ 0.00200284]
#   [ 0.21411173]
#   [ 0.04164549]
#   [-0.06480794]
#   [-0.01155534]
#   [ 0.02292937]
#   [-0.04816508]
#   [ 0.08186167]
#   [ 0.01414758]
#   [-0.06112414]
#   [-0.12809086]
#   [ 0.02532313]
#   [ 0.13376537]
#   [-0.0723435 ]
#   [ 0.08319715]
#   [-0.1926507 ]]]
# 5 ['']
# d_loss 0.712989866733551
# d_acc: 0.5
# g_loss [0.7188583016395569, 0.6363636255264282]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 161.13399  ]
#   [-225.93993  ]
#   [-306.33502  ]
#   [-397.46106  ]
#   [ 839.93744  ]
#   [-168.1755   ]
#   [ 603.25244  ]
#   [-213.20474  ]
#   [ 383.37228  ]
#   [ 548.0365   ]
#   [  43.211063 ]
#   [-118.05597  ]
#   [ 357.31653  ]
#   [ 288.35876  ]
#   [ 117.65087  ]
#   [-115.116066 ]
#   [ 453.1302   ]
#   [ 172.83305  ]
#   [ -92.53312  ]
#   [ 122.90895  ]
#   [ 240.68726  ]
#   [-258.1475   ]
#   [ 658.67346  ]
#   [ 586.9312   ]
#   [ 827.1694   ]
#   [ 415.7616   ]
#   [ -11.6905365]
#   [-676.9287   ]
#   [ 350.40533  ]
#   [-257.70496  ]
#   [-152.23102  ]
#   [ 422.8645   ]
#   [ -40.61657  ]
#   [-358.88638  ]
#   [ 386.61478  ]
#   [ 896.4407   ]
#   [ 485.48154  ]
#   [ 148.71657  ]
#   [ 548.45404  ]
#   [ -61.21869  ]
#   [ -54.960117 ]
#   [ -29.821878 ]
#   [ 888.32477  ]
#   [ 160.64609  ]
#   [-336.37958  ]
#   [ -10.739594 ]
#   [ 129.81096  ]
#   [-135.16594  ]
#   [ 302.59198  ]
#   [ 143.54604  ]
#   [-126.85943  ]
#   [-371.12692  ]
#   [ 137.05229  ]
#   [ 534.3742   ]
#   [-186.61615  ]
#   [ 475.4253   ]
#   [-762.74365  ]]]
# 6 [" honor surprise decided spiked heroes four city real jobs worse georgia had challenged cases off down enter no i’m we’ve already 730 single chag education award for staying artists 888 stay heart out assumptions side forward house worse his he was way remember it it’s next wear control line hopeful lives unconscionable what's moment something"]
# d_loss 0.6960800588130951
# d_acc: 0.4545454680919647
# g_loss [0.7342835664749146, 0.7575757503509521]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 9.5093623e-05]
#   [-1.2395890e-02]
#   [-5.1457360e-03]
#   [-1.0983886e-02]
#   [ 3.8171630e-02]
#   [ 2.7490784e-03]
#   [ 4.3365467e-02]
#   [ 5.4277573e-04]
#   [ 3.0128166e-02]
#   [ 4.0745247e-02]
#   [ 1.5413187e-02]
#   [ 4.8493478e-03]
#   [ 3.2512672e-02]
#   [ 3.0800752e-02]
#   [ 2.3964487e-02]
#   [-9.3517173e-04]
#   [ 3.4162104e-02]
#   [ 1.9567143e-02]
#   [ 7.2577037e-03]
#   [ 9.9646086e-03]
#   [ 1.6676180e-02]
#   [-2.5923736e-03]
#   [ 4.6613526e-02]
#   [ 3.5123568e-02]
#   [ 4.7464013e-02]
#   [ 2.7420318e-02]
#   [ 1.3744170e-02]
#   [-2.2288954e-02]
#   [ 1.5765183e-02]
#   [-1.3791531e-02]
#   [ 1.0789218e-02]
#   [ 3.4262117e-02]
#   [-1.1312303e-02]
#   [ 2.9981323e-03]
#   [ 4.0061273e-02]
#   [ 5.7364412e-02]
#   [ 3.6932930e-02]
#   [ 6.7962264e-03]
#   [ 3.6708627e-02]
#   [-7.3630176e-04]
#   [-1.0201577e-02]
#   [-5.2249143e-03]
#   [ 5.2231014e-02]
#   [ 1.6114468e-02]
#   [-2.1303022e-02]
#   [-7.9428987e-04]
#   [ 1.0535544e-02]
#   [-1.9673053e-02]
#   [ 1.7088592e-02]
#   [-7.7179433e-03]
#   [-2.6258267e-02]
#   [-3.7457012e-02]
#   [-3.2966016e-03]
#   [ 2.6796050e-02]
#   [-3.2467686e-02]
#   [ 3.0825529e-03]
#   [-5.5410542e-02]]]
# 7 ['']
# d_loss 0.6920722424983978
# d_acc: 0.5
# g_loss [0.7168916463851929, 0.8181818127632141]
# (1, 57, 1)
# (1, 57, 1)
# [[[  550.9885  ]
#   [ -569.17017 ]
#   [ -765.19543 ]
#   [-1058.0878  ]
#   [ 2517.6665  ]
#   [ -377.72897 ]
#   [ 1817.101   ]
#   [ -509.4973  ]
#   [ 1188.83    ]
#   [ 1682.2543  ]
#   [  209.6131  ]
#   [ -242.61632 ]
#   [ 1122.3947  ]
#   [  907.0277  ]
#   [  446.5816  ]
#   [ -276.88824 ]
#   [ 1367.3618  ]
#   [  583.5611  ]
#   [ -242.36734 ]
#   [  404.2226  ]
#   [  755.27783 ]
#   [ -687.6856  ]
#   [ 1927.4475  ]
#   [ 1710.2491  ]
#   [ 2394.1958  ]
#   [ 1202.4701  ]
#   [   -7.691174]
#   [-1905.134   ]
#   [ 1027.0316  ]
#   [ -738.2694  ]
#   [ -417.1496  ]
#   [ 1198.6636  ]
#   [ -100.665375]
#   [-1005.76495 ]
#   [ 1105.1243  ]
#   [ 2567.3572  ]
#   [ 1392.2523  ]
#   [  420.7583  ]
#   [ 1573.4387  ]
#   [ -186.7912  ]
#   [ -139.42429 ]
#   [  -71.91836 ]
#   [ 2531.9958  ]
#   [  458.81082 ]
#   [ -970.1672  ]
#   [  -47.54045 ]
#   [  363.5092  ]
#   [ -397.3195  ]
#   [  876.5159  ]
#   [  397.8059  ]
#   [ -363.19394 ]
#   [-1057.0225  ]
#   [  395.5153  ]
#   [ 1529.0709  ]
#   [ -538.06433 ]
#   [ 1365.2657  ]
#   [-2176.796   ]]]
# 8 [" until visual 773 break walks shaped lead against together remind lead didn't outstanding november our supreme actors help able what's land let’s dr how truth spiked spiked truth club evicted"]
# d_loss 0.7129058539867401
# d_acc: 0.6666666865348816
# g_loss [0.6880806088447571, 0.4545454680919647]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 2.41258373e+01]
#   [ 3.27955856e+01]
#   [ 1.21551064e+02]
#   [ 4.95111542e+01]
#   [-1.69163849e+02]
#   [ 2.86563778e+01]
#   [-1.85089447e+02]
#   [ 5.80347121e-01]
#   [-1.59463318e+02]
#   [-1.18830017e+02]
#   [-6.08470345e+00]
#   [ 4.13141518e+01]
#   [-2.17612724e+01]
#   [-8.48967285e+01]
#   [ 5.86905098e+00]
#   [-1.66178093e+01]
#   [-1.49259415e+02]
#   [ 5.10243645e+01]
#   [ 3.60055275e+01]
#   [-8.08243408e+01]
#   [-3.40219460e+01]
#   [ 3.28627281e+01]
#   [-1.23779678e+02]
#   [-1.63486420e+02]
#   [-1.86120575e+02]
#   [-9.90517883e+01]
#   [ 5.85986423e+00]
#   [ 8.35205002e+01]
#   [-4.33041267e+01]
#   [ 1.52815390e+01]
#   [ 6.16469498e+01]
#   [-1.22316063e+02]
#   [ 5.76732330e+01]
#   [ 1.35310028e+02]
#   [-9.45379868e+01]
#   [-2.27246124e+02]
#   [-7.62379227e+01]
#   [-5.45963821e+01]
#   [-1.08077927e+02]
#   [ 2.48630867e+01]
#   [ 7.88461533e+01]
#   [ 7.50346222e+01]
#   [-2.23879456e+02]
#   [-1.64572411e+01]
#   [ 1.59293098e+01]
#   [-6.79410324e+01]
#   [-6.91927490e+01]
#   [-7.15992785e+00]
#   [-3.22198715e+01]
#   [-6.64888458e+01]
#   [ 1.64781113e+01]
#   [ 8.54738541e+01]
#   [-8.55499282e-02]
#   [-1.13152374e+02]
#   [ 3.79527931e+01]
#   [-6.49936371e+01]
#   [ 1.49155075e+02]]]
# 9 [" can or best by poll at you’re book had of get my better in your were year us love have or everyone she what's you're in plan georgia that his we’ve early next world when what he keep can president not critical your that an lot our or about your those take will democracy were"]
# d_loss 0.7001121342182159
# d_acc: 0.5000000149011612
# g_loss [0.6801818013191223, 0.4848484992980957]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 128.00217  ]
#   [-106.233894 ]
#   [-145.36194  ]
#   [-207.3836   ]
#   [ 551.39594  ]
#   [ -62.646008 ]
#   [ 402.10526  ]
#   [ -90.61328  ]
#   [ 269.52368  ]
#   [ 377.76297  ]
#   [  59.286    ]
#   [ -37.233677 ]
#   [ 252.78842  ]
#   [ 207.17892  ]
#   [ 111.6359   ]
#   [ -47.576588 ]
#   [ 302.69315  ]
#   [ 135.24486  ]
#   [ -46.57385  ]
#   [  95.30534  ]
#   [ 173.68877  ]
#   [-136.26761  ]
#   [ 415.88846  ]
#   [ 368.65674  ]
#   [ 514.022    ]
#   [ 257.92703  ]
#   [   3.2899992]
#   [-395.43408  ]
#   [ 221.25446  ]
#   [-152.6451   ]
#   [ -89.303894 ]
#   [ 255.46696  ]
#   [ -21.90179  ]
#   [-212.98842  ]
#   [ 235.89554  ]
#   [ 546.8918   ]
#   [ 294.3097   ]
#   [  89.97278  ]
#   [ 333.16617  ]
#   [ -42.893234 ]
#   [ -28.276836 ]
#   [ -16.551294 ]
#   [ 537.50726  ]
#   [  98.32935  ]
#   [-203.26147  ]
#   [ -12.063398 ]
#   [  78.194176 ]
#   [ -84.03548  ]
#   [ 185.86221  ]
#   [  84.82399  ]
#   [ -78.51229  ]
#   [-223.68993  ]
#   [  81.84387  ]
#   [ 325.93207  ]
#   [-113.99538  ]
#   [ 287.98962  ]
#   [-461.75757  ]]]
# 10 [' person michelle health middle widely years stole life friends break change will state middle communities how wear next time any call than award helpless optimism 888 and club much stay save takes my available other unemployment around save protections day at your holidays up use is president better you’re better president critical drop virus take pay king']
# d_loss 0.707510769367218
# d_acc: 0.5151515305042267
# g_loss [0.689679741859436, 0.39393940567970276]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 250.81384 ]
#   [-181.39716 ]
#   [-238.90768 ]
#   [-365.4826  ]
#   [1019.6658  ]
#   [-106.593025]
#   [ 736.4313  ]
#   [-156.84262 ]
#   [ 497.7777  ]
#   [ 709.65967 ]
#   [ 119.50221 ]
#   [ -52.30508 ]
#   [ 479.95352 ]
#   [ 385.62753 ]
#   [ 224.92119 ]
#   [ -77.58949 ]
#   [ 554.5544  ]
#   [ 265.4512  ]
#   [ -80.06251 ]
#   [ 176.20273 ]
#   [ 331.12595 ]
#   [-242.9752  ]
#   [ 762.2067  ]
#   [ 671.2491  ]
#   [ 942.64655 ]
#   [ 467.3526  ]
#   [   9.555196]
#   [-718.6847  ]
#   [ 409.43185 ]
#   [-276.426   ]
#   [-161.31528 ]
#   [ 458.30463 ]
#   [ -33.02448 ]
#   [-379.95984 ]
#   [ 428.47977 ]
#   [ 991.6663  ]
#   [ 533.2447  ]
#   [ 159.26666 ]
#   [ 609.23334 ]
#   [ -81.44777 ]
#   [ -47.05127 ]
#   [ -19.18953 ]
#   [ 973.7331  ]
#   [ 182.63    ]
#   [-374.72998 ]
#   [ -34.352062]
#   [ 139.21489 ]
#   [-157.77931 ]
#   [ 343.39877 ]
#   [ 149.58789 ]
#   [-144.96898 ]
#   [-402.88782 ]
#   [ 149.70154 ]
#   [ 592.8762  ]
#   [-209.31082 ]
#   [ 527.5509  ]
#   [-839.1035  ]]]
# 11 [' gave box send loved michelle strength while higher reform left work lewis south show family alleviate tomorrow love 1 building lead something recently taxes this yourselves legacy together honor dr one breathe players merry book listening drop how make issues demands have land role fairly were these stole were continue shaped different heroes']
# d_loss 0.7079653441905975
# d_acc: 0.5000000149011612
# g_loss [0.702807605266571, 0.5151515007019043]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 160.78717 ]
#   [-107.67711 ]
#   [-145.04291 ]
#   [-221.88776 ]
#   [ 645.73505 ]
#   [ -58.463516]
#   [ 470.64676 ]
#   [ -88.656425]
#   [ 320.61926 ]
#   [ 451.02322 ]
#   [  81.295074]
#   [ -26.930025]
#   [ 305.17856 ]
#   [ 248.51096 ]
#   [ 146.22908 ]
#   [ -44.50759 ]
#   [ 354.52414 ]
#   [ 169.45738 ]
#   [ -48.654343]
#   [ 115.89779 ]
#   [ 210.98347 ]
#   [-147.30434 ]
#   [ 480.24368 ]
#   [ 423.7864  ]
#   [ 591.33167 ]
#   [ 294.87442 ]
#   [   8.003631]
#   [-445.46902 ]
#   [ 256.73804 ]
#   [-172.32556 ]
#   [-100.4241  ]
#   [ 288.39597 ]
#   [ -21.931633]
#   [-238.69919 ]
#   [ 268.76227 ]
#   [ 622.5769  ]
#   [ 334.4069  ]
#   [ 100.947845]
#   [ 380.4144  ]
#   [ -51.656742]
#   [ -29.36673 ]
#   [ -15.441385]
#   [ 610.3826  ]
#   [ 113.21839 ]
#   [-232.7211  ]
#   [ -19.282467]
#   [  88.03008 ]
#   [ -97.760796]
#   [ 213.93428 ]
#   [  94.38869 ]
#   [ -90.50487 ]
#   [-252.91129 ]
#   [  93.099495]
#   [ 371.59668 ]
#   [-130.52391 ]
#   [ 328.9716  ]
#   [-525.1977  ]]]
# 12 [' way proud health much willingness like violence covid kamala wore drop election came congratulations during them alston poll we’re down should white surely unlike high around you fight questions no help cases my send respond insight political help historic year was that songs take others make covid who real world life state folks hopeful americans voices accomplished']
# d_loss 0.6888042390346527
# d_acc: 0.3484848588705063
# g_loss [0.7322044968605042, 0.6363636255264282]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 203.55956 ]
#   [-123.46648 ]
#   [-164.29935 ]
#   [-261.6349  ]
#   [ 791.85376 ]
#   [ -64.359764]
#   [ 576.5535  ]
#   [-100.32292 ]
#   [ 394.90442 ]
#   [ 557.4723  ]
#   [ 105.82506 ]
#   [ -24.217903]
#   [ 379.42493 ]
#   [ 307.56943 ]
#   [ 187.55974 ]
#   [ -49.256725]
#   [ 434.27707 ]
#   [ 214.30148 ]
#   [ -56.453045]
#   [ 143.97708 ]
#   [ 262.76212 ]
#   [-174.52863 ]
#   [ 585.59735 ]
#   [ 515.2497  ]
#   [ 719.6597  ]
#   [ 357.86838 ]
#   [  11.881784]
#   [-537.93945 ]
#   [ 313.90167 ]
#   [-208.3858  ]
#   [-120.76709 ]
#   [ 347.6079  ]
#   [ -24.407087]
#   [-286.4301  ]
#   [ 325.4108  ]
#   [ 753.979   ]
#   [ 405.02014 ]
#   [ 121.2082  ]
#   [ 461.56458 ]
#   [ -64.12902 ]
#   [ -33.45752 ]
#   [ -16.461746]
#   [ 738.6459  ]
#   [ 138.08292 ]
#   [-283.44174 ]
#   [ -27.018053]
#   [ 106.03712 ]
#   [-119.82219 ]
#   [ 260.64542 ]
#   [ 112.91246 ]
#   [-110.51688 ]
#   [-305.40265 ]
#   [ 113.16523 ]
#   [ 450.7537  ]
#   [-158.49841 ]
#   [ 399.72397 ]
#   [-636.39185 ]]]
# 13 [' use everyone i’ve senate two democracy also help brothas inside voting can breathe memoir still by unassuming feeling because control voice protection glimmers come ticket challenged for holidays veterans whose ever crucial can can’t virus party changed best king democracy one your supreme promised yours country michelle left elect across into came take marched support pitches aligns']
# d_loss 0.7303982079029083
# d_acc: 0.42424243688583374
# g_loss [0.683863639831543, 0.7272727489471436]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 203.62268 ]
#   [-113.83842 ]
#   [-151.42825 ]
#   [-247.43286 ]
#   [ 775.75543 ]
#   [ -55.754814]
#   [ 566.03796 ]
#   [ -89.995026]
#   [ 389.58038 ]
#   [ 548.94867 ]
#   [ 109.52624 ]
#   [ -16.73992 ]
#   [ 375.02087 ]
#   [ 304.27606 ]
#   [ 189.57414 ]
#   [ -43.930614]
#   [ 426.30933 ]
#   [ 214.07965 ]
#   [ -52.81155 ]
#   [ 143.44604 ]
#   [ 260.01392 ]
#   [-165.35674 ]
#   [ 571.15704 ]
#   [ 501.88538 ]
#   [ 699.94806 ]
#   [ 348.2553  ]
#   [  13.440361]
#   [-519.18274 ]
#   [ 306.1446  ]
#   [-201.7854  ]
#   [-116.28001 ]
#   [ 336.5994  ]
#   [ -22.874775]
#   [-276.3109  ]
#   [ 315.55807 ]
#   [ 731.53375 ]
#   [ 393.0435  ]
#   [ 117.346596]
#   [ 447.52747 ]
#   [ -63.216972]
#   [ -31.083475]
#   [ -15.960559]
#   [ 715.99615 ]
#   [ 133.95486 ]
#   [-275.1326  ]
#   [ -27.445614]
#   [ 102.676895]
#   [-116.67563 ]
#   [ 253.17613 ]
#   [ 108.95051 ]
#   [-107.559235]
#   [-295.93466 ]
#   [ 109.82105 ]
#   [ 437.59058 ]
#   [-153.70924 ]
#   [ 387.8649  ]
#   [-617.2036  ]]]
# 14 [' use take going everything involved people expanded save bookstores worse new your announce experts week georgia match feeling work control elect u enjoyed fundamental office display vote reach decided join home remember as together service quarterback smart off beginning before do that local sure runoff country things home polls keep proud first new example difference owned mixtapes']
# d_loss 0.6893302798271179
# d_acc: 0.6666666865348816
# g_loss [0.7158700227737427, 0.4545454680919647]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 310.17166 ]
#   [-158.36028 ]
#   [-206.09981 ]
#   [-354.53052 ]
#   [1147.2887  ]
#   [ -74.743004]
#   [ 834.6303  ]
#   [-124.81098 ]
#   [ 575.9909  ]
#   [ 817.5088  ]
#   [ 169.9909  ]
#   [ -13.893777]
#   [ 562.2636  ]
#   [ 452.49496 ]
#   [ 291.4956  ]
#   [ -59.536465]
#   [ 628.12866 ]
#   [ 326.54688 ]
#   [ -73.871864]
#   [ 212.79639 ]
#   [ 390.0626  ]
#   [-237.91225 ]
#   [ 841.2455  ]
#   [ 735.94885 ]
#   [1028.9514  ]
#   [ 510.1851  ]
#   [  22.23393 ]
#   [-759.6006  ]
#   [ 452.4571  ]
#   [-295.70352 ]
#   [-168.80782 ]
#   [ 489.4207  ]
#   [ -29.451519]
#   [-399.07925 ]
#   [ 461.2172  ]
#   [1069.649   ]
#   [ 575.6     ]
#   [ 169.68161 ]
#   [ 656.4099  ]
#   [ -94.622955]
#   [ -41.644894]
#   [ -18.524103]
#   [1046.4286  ]
#   [ 197.8819  ]
#   [-406.26724 ]
#   [ -46.875973]
#   [ 148.69713 ]
#   [-173.45752 ]
#   [ 373.27466 ]
#   [ 156.93672 ]
#   [-159.06554 ]
#   [-431.93594 ]
#   [ 162.05438 ]
#   [ 641.5595  ]
#   [-225.62247 ]
#   [ 570.4531  ]
#   [-904.15625 ]]]
# 15 [' playing support protecting alston me chadwick never celebrating social poll vote theatrical defended else change wrote making only available play seen – testament stepped as class defended first four close was pitches king celebrating poll decision world get we upcoming paved time house call challenge while book thoughts build served surprise storytelling']
# d_loss 0.7238774001598358
# d_acc: 0.5
# g_loss [0.7185041308403015, 0.42424243688583374]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 106.74656  ]
#   [ -53.05189  ]
#   [ -73.097855 ]
#   [-120.85179  ]
#   [ 402.03455  ]
#   [ -21.777754 ]
#   [ 296.60056  ]
#   [ -38.489967 ]
#   [ 205.78745  ]
#   [ 286.501    ]
#   [  62.22366  ]
#   [  -3.5813193]
#   [ 195.9967   ]
#   [ 161.50693  ]
#   [ 102.22281  ]
#   [ -19.405323 ]
#   [ 223.0678   ]
#   [ 112.8082   ]
#   [ -25.279648 ]
#   [  77.24204  ]
#   [ 136.46126  ]
#   [ -80.37708  ]
#   [ 294.84927  ]
#   [ 258.90045  ]
#   [ 358.57446  ]
#   [ 179.81137  ]
#   [   8.730607 ]
#   [-261.4289   ]
#   [ 156.84708  ]
#   [-102.503944 ]
#   [ -59.240818 ]
#   [ 173.20744  ]
#   [ -12.491911 ]
#   [-140.96608  ]
#   [ 161.55957  ]
#   [ 375.05945  ]
#   [ 201.20372  ]
#   [  61.1424   ]
#   [ 227.80287  ]
#   [ -33.35363  ]
#   [ -15.311178 ]
#   [ -10.245202 ]
#   [ 366.04895  ]
#   [  67.68392  ]
#   [-138.76451  ]
#   [ -13.027801 ]
#   [  52.772377 ]
#   [ -59.056297 ]
#   [ 128.62292  ]
#   [  56.00665  ]
#   [ -55.325344 ]
#   [-152.17386  ]
#   [  55.540318 ]
#   [ 224.19344  ]
#   [ -78.03494  ]
#   [ 196.97247  ]
#   [-315.26553  ]]]
# 16 [' michelle more only ever stole my 19 right conditions can’t years and protect honor things make critical across if family than love around 730 assumptions heard you senate while things change call is got honor announce join his when one that it one’s an promised vote work change person because people stay people show president register service']
# d_loss 0.7143748104572296
# d_acc: 0.5151515156030655
# g_loss [0.6808860898017883, 0.4545454680919647]
# (1, 57, 1)
# (1, 57, 1)
# [[[  492.16782 ]
#   [ -218.27055 ]
#   [ -276.78204 ]
#   [ -513.28174 ]
#   [ 1754.256   ]
#   [  -94.21633 ]
#   [ 1274.4147  ]
#   [ -167.4364  ]
#   [  885.5154  ]
#   [ 1263.1162  ]
#   [  278.58185 ]
#   [    3.658365]
#   [  875.5124  ]
#   [  699.0969  ]
#   [  469.67114 ]
#   [  -77.47962 ]
#   [  957.9456  ]
#   [  519.1561  ]
#   [ -103.49175 ]
#   [  329.38522 ]
#   [  608.2774  ]
#   [ -346.81842 ]
#   [ 1278.1829  ]
#   [ 1112.3623  ]
#   [ 1557.4834  ]
#   [  770.2757  ]
#   [   40.16915 ]
#   [-1138.313   ]
#   [  689.8619  ]
#   [ -444.19785 ]
#   [ -250.7254  ]
#   [  732.205   ]
#   [  -37.40378 ]
#   [ -591.7611  ]
#   [  693.9521  ]
#   [ 1608.2914  ]
#   [  867.4752  ]
#   [  251.79152 ]
#   [  989.54675 ]
#   [ -146.50757 ]
#   [  -55.33503 ]
#   [  -20.906044]
#   [ 1571.265   ]
#   [  300.18228 ]
#   [ -616.0927  ]
#   [  -82.137764]
#   [  220.71194 ]
#   [ -265.1659  ]
#   [  566.76654 ]
#   [  231.97714 ]
#   [ -241.84825 ]
#   [ -647.86774 ]
#   [  245.63684 ]
#   [  967.3601  ]
#   [ -340.89474 ]
#   [  861.9012  ]
#   [-1361.3184  ]]]
# 17 [' jon obama together ringing world again virtually and office tests family reach they depends fred labor planning out place clearly gave washington will high here every during people on too school some delivering tomorrow expanded baseball once reason masks volunteer']
# d_loss 0.6960061490535736
# d_acc: 0.3636363595724106
# g_loss [0.7156641483306885, 0.6969696879386902]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 152.03337  ]
#   [ -66.0999   ]
#   [ -88.668076 ]
#   [-156.99336  ]
#   [ 550.0911   ]
#   [ -24.394653 ]
#   [ 404.81848  ]
#   [ -46.031246 ]
#   [ 282.69043  ]
#   [ 395.00272  ]
#   [  89.925835 ]
#   [   2.3976994]
#   [ 272.49902  ]
#   [ 222.55014  ]
#   [ 146.16505  ]
#   [ -22.43809  ]
#   [ 304.70175  ]
#   [ 159.6772   ]
#   [ -32.298073 ]
#   [ 106.99984  ]
#   [ 189.49559  ]
#   [-105.266716 ]
#   [ 400.16553  ]
#   [ 350.40488  ]
#   [ 485.7131   ]
#   [ 242.58557  ]
#   [  13.423773 ]
#   [-351.27826  ]
#   [ 213.95575  ]
#   [-138.21999  ]
#   [ -78.379364 ]
#   [ 231.36337  ]
#   [ -14.765076 ]
#   [-187.5087   ]
#   [ 217.34303  ]
#   [ 504.62723  ]
#   [ 271.25064  ]
#   [  80.93501  ]
#   [ 307.4574   ]
#   [ -45.64765  ]
#   [ -18.744486 ]
#   [ -11.856383 ]
#   [ 492.21613  ]
#   [  91.90954  ]
#   [-189.05481  ]
#   [ -20.575071 ]
#   [  70.36953  ]
#   [ -80.990295 ]
#   [ 174.66725  ]
#   [  74.18591  ]
#   [ -74.71753  ]
#   [-203.70215  ]
#   [  75.47554  ]
#   [ 302.12775  ]
#   [-105.61692  ]
#   [ 266.8205   ]
#   [-424.78305  ]]]
# 18 [" stay about covid while until can didn't time another club save the ways black during as experts book or michelle week voting aimed artists forward lead vote alma real promised president baseball all still working powerful tested love memoir be we for jon climate week on could love protection me me use not wear voting far 96"]
# d_loss 0.7083805203437805
# d_acc: 0.5454545617103577
# g_loss [0.6961207985877991, 0.3333333432674408]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 1.5954158 ]
#   [-1.325629  ]
#   [-3.794845  ]
#   [-2.78235   ]
#   [10.757404  ]
#   [-0.09217328]
#   [ 9.815777  ]
#   [ 0.02451096]
#   [ 7.308258  ]
#   [ 7.6588283 ]
#   [ 1.646365  ]
#   [-0.4877229 ]
#   [ 4.086536  ]
#   [ 4.976677  ]
#   [ 1.6980083 ]
#   [-0.12059135]
#   [ 7.297342  ]
#   [ 1.1994643 ]
#   [-0.9025698 ]
#   [ 3.2927704 ]
#   [ 3.2234044 ]
#   [-1.8442365 ]
#   [ 8.11965   ]
#   [ 8.11174   ]
#   [ 9.794032  ]
#   [ 5.642512  ]
#   [ 0.27120712]
#   [-6.023576  ]
#   [ 3.7422767 ]
#   [-2.1232104 ]
#   [-2.027855  ]
#   [ 6.0527387 ]
#   [-1.4364429 ]
#   [-5.331652  ]
#   [ 4.8155575 ]
#   [11.314783  ]
#   [ 5.545354  ]
#   [ 2.260001  ]
#   [ 5.894838  ]
#   [-0.95577544]
#   [-1.5638916 ]
#   [-2.371543  ]
#   [11.058187  ]
#   [ 1.3339803 ]
#   [-2.629325  ]
#   [ 1.3756475 ]
#   [ 2.3475919 ]
#   [-0.70898306]
#   [ 2.837231  ]
#   [ 2.5485497 ]
#   [-1.3510786 ]
#   [-4.648405  ]
#   [ 1.1498536 ]
#   [ 6.5187836 ]
#   [-2.2016256 ]
#   [ 4.6367717 ]
#   [-8.790455  ]]]
# 19 [' to to and the it this our our to a a to our to and and to you you this in of and the the of to in a for in the in to the for to the to the the the to a to of the a you']
# d_loss 0.6943527162075043
# d_acc: 0.530303031206131
# g_loss [0.686931312084198, 0.3333333432674408]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 298.44086 ]
#   [-115.02732 ]
#   [-152.07239 ]
#   [-286.06195 ]
#   [1045.8951  ]
#   [ -38.474022]
#   [ 767.1948  ]
#   [ -77.370735]
#   [ 517.4425  ]
#   [ 765.9855  ]
#   [ 181.80902 ]
#   [  30.178444]
#   [ 525.25995 ]
#   [ 425.8148  ]
#   [ 280.19098 ]
#   [ -39.51966 ]
#   [ 577.0812  ]
#   [ 312.04572 ]
#   [ -57.604977]
#   [ 204.74374 ]
#   [ 363.63318 ]
#   [-193.3952  ]
#   [ 755.2581  ]
#   [ 659.41315 ]
#   [ 914.10016 ]
#   [ 456.03204 ]
#   [  27.918583]
#   [-657.8303  ]
#   [ 405.6268  ]
#   [-259.8068  ]
#   [-144.10841 ]
#   [ 431.2447  ]
#   [ -23.668497]
#   [-347.63605 ]
#   [ 406.71167 ]
#   [ 944.38684 ]
#   [ 509.81137 ]
#   [ 148.94162 ]
#   [ 577.273   ]
#   [ -86.103134]
#   [ -31.74279 ]
#   [ -19.305067]
#   [ 921.22235 ]
#   [ 172.854   ]
#   [-358.1064  ]
#   [ -43.59987 ]
#   [ 130.43115 ]
#   [-153.82481 ]
#   [ 330.0114  ]
#   [ 137.34566 ]
#   [-140.43533 ]
#   [-380.44495 ]
#   [ 143.6041  ]
#   [ 567.1656  ]
#   [-199.30885 ]
#   [ 503.0397  ]
#   [-796.849   ]]]
# 20 [' then down stay can’t right 9687 family ahead 773 box from accomplished mark blessings are clarified determination early preexisting truth workers outstanding cast worth country chance changed 5816 these thoughts with crucial paved walks house clarified care do make no assumptions georgia americans difference stake lives got historic control list young individual fires']
# d_loss 0.6929590106010437
# d_acc: 0.530303031206131
# g_loss [0.6844860315322876, 0.3333333432674408]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 116.53244 ]
#   [ -43.639446]
#   [ -60.424477]
#   [-111.16442 ]
#   [ 414.29266 ]
#   [ -13.093733]
#   [ 305.8286  ]
#   [ -27.81142 ]
#   [ 203.40771 ]
#   [ 305.9805  ]
#   [  74.554276]
#   [  15.269391]
#   [ 207.9296  ]
#   [ 171.03932 ]
#   [ 110.64543 ]
#   [ -14.775631]
#   [ 230.04028 ]
#   [ 122.811676]
#   [ -22.246004]
#   [  82.52263 ]
#   [ 144.44695 ]
#   [ -74.58734 ]
#   [ 299.35574 ]
#   [ 261.54657 ]
#   [ 361.37283 ]
#   [ 181.00145 ]
#   [  11.651648]
#   [-257.5376  ]
#   [ 159.55403 ]
#   [-101.99929 ]
#   [ -57.78465 ]
#   [ 171.61876 ]
#   [ -10.780388]
#   [-137.91904 ]
#   [ 161.15895 ]
#   [ 374.6362  ]
#   [ 201.1478  ]
#   [  60.43098 ]
#   [ 227.54617 ]
#   [ -34.986687]
#   [ -12.959055]
#   [  -9.298176]
#   [ 364.61447 ]
#   [  67.90803 ]
#   [-139.38818 ]
#   [ -15.731676]
#   [  52.13396 ]
#   [ -60.113186]
#   [ 129.40746 ]
#   [  54.706017]
#   [ -55.9079  ]
#   [-151.31026 ]
#   [  55.67318 ]
#   [ 224.42552 ]
#   [ -78.048874]
#   [ 197.32094 ]
#   [-314.74908 ]]]
# 21 [' home georgia hope communities rare vote came country use came me that middle many into all faced we’ve as some these me know senate disinformation box for 888 book most early many it lives honor demands join hope when have is this soon an land that work hope it’s he people going people show president upcoming well']
# d_loss 0.6836277544498444
# d_acc: 0.5000000149011612
# g_loss [0.6833381652832031, 0.3333333432674408]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 0.00532952]
#   [-0.00488104]
#   [ 0.00102599]
#   [-0.00495783]
#   [ 0.04842872]
#   [ 0.00955062]
#   [ 0.05177639]
#   [ 0.0080612 ]
#   [ 0.03572922]
#   [ 0.04957394]
#   [ 0.0218914 ]
#   [ 0.01212823]
#   [ 0.03864191]
#   [ 0.03696485]
#   [ 0.02979733]
#   [ 0.00244721]
#   [ 0.039972  ]
#   [ 0.02439903]
#   [ 0.0087646 ]
#   [ 0.01415445]
#   [ 0.02104053]
#   [ 0.00103219]
#   [ 0.04983727]
#   [ 0.03807525]
#   [ 0.049607  ]
#   [ 0.02909711]
#   [ 0.01556909]
#   [-0.01968564]
#   [ 0.0172258 ]
#   [-0.01348611]
#   [ 0.01150912]
#   [ 0.03470367]
#   [-0.01119697]
#   [ 0.0035396 ]
#   [ 0.0404183 ]
#   [ 0.05846902]
#   [ 0.03753688]
#   [ 0.00697725]
#   [ 0.03671535]
#   [-0.00137808]
#   [-0.00958356]
#   [-0.0062722 ]
#   [ 0.05275308]
#   [ 0.01574135]
#   [-0.0211045 ]
#   [-0.0008057 ]
#   [ 0.01076877]
#   [-0.0196431 ]
#   [ 0.01720038]
#   [-0.00761012]
#   [-0.02634285]
#   [-0.03769181]
#   [-0.00326807]
#   [ 0.02741561]
#   [-0.0326312 ]
#   [ 0.00315402]
#   [-0.0557546 ]]]
# 22 ['']
# d_loss 0.6836503446102142
# d_acc: 0.469696968793869
# g_loss [0.6925963759422302, 0.4545454680919647]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 219.92416 ]
#   [ -99.01335 ]
#   [ -94.05654 ]
#   [-235.62616 ]
#   [ 802.6208  ]
#   [ -39.12122 ]
#   [ 621.17957 ]
#   [ -62.054188]
#   [ 411.57526 ]
#   [ 618.3918  ]
#   [ 151.87941 ]
#   [  21.764154]
#   [ 409.3889  ]
#   [ 333.56192 ]
#   [ 206.46228 ]
#   [ -46.49139 ]
#   [ 465.62277 ]
#   [ 250.24968 ]
#   [ -40.69542 ]
#   [ 165.19725 ]
#   [ 288.05396 ]
#   [-145.41405 ]
#   [ 591.5399  ]
#   [ 515.8246  ]
#   [ 711.2592  ]
#   [ 355.97598 ]
#   [  24.788475]
#   [-508.5607  ]
#   [ 317.50897 ]
#   [-203.20819 ]
#   [-109.05471 ]
#   [ 335.59207 ]
#   [ -17.269217]
#   [-268.42264 ]
#   [ 316.27768 ]
#   [ 734.25244 ]
#   [ 398.61444 ]
#   [ 115.2786  ]
#   [ 447.66327 ]
#   [ -66.96251 ]
#   [ -21.635096]
#   [ -16.948349]
#   [ 715.1671  ]
#   [ 133.6165  ]
#   [-278.90353 ]
#   [ -34.475037]
#   [ 100.21382 ]
#   [-122.484116]
#   [ 256.92163 ]
#   [ 106.347786]
#   [-108.79439 ]
#   [-295.78647 ]
#   [ 112.31161 ]
#   [ 441.24323 ]
#   [-154.72014 ]
#   [ 391.13412 ]
#   [-619.73804 ]]]
# 23 [" presidential you're world other does are goal years career music going my legacy protections protecting time clubs gave out u cases health high come schools provoked can unimaginable thank use new there’s i respond grateful team cleats down beginning about my your local sure virtually have help we’ve questions michelle keep first across accords center wanted played"]
# d_loss 0.7087387442588806
# d_acc: 0.5454545617103577
# g_loss [0.6932519674301147, 0.5454545617103577]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 109.15715  ]
#   [ -59.51551  ]
#   [ -38.922794 ]
#   [-134.77957  ]
#   [ 418.9446   ]
#   [ -28.890287 ]
#   [ 337.9762   ]
#   [ -38.79055  ]
#   [ 224.50165  ]
#   [ 335.08774  ]
#   [  83.449585 ]
#   [   4.331092 ]
#   [ 217.47192  ]
#   [ 176.71577  ]
#   [ 106.0127   ]
#   [ -33.266785 ]
#   [ 252.52313  ]
#   [ 136.79233  ]
#   [ -19.589344 ]
#   [  87.71508  ]
#   [ 155.90369  ]
#   [ -76.485565 ]
#   [ 316.84497  ]
#   [ 274.3222   ]
#   [ 379.8295   ]
#   [ 188.96341  ]
#   [  13.993835 ]
#   [-271.6434   ]
#   [ 170.0324   ]
#   [-109.38658  ]
#   [ -58.083958 ]
#   [ 177.71309  ]
#   [  -8.307161 ]
#   [-140.0402   ]
#   [ 168.24774  ]
#   [ 391.35358  ]
#   [ 212.57304  ]
#   [  61.735985 ]
#   [ 238.66678  ]
#   [ -36.88339  ]
#   [  -9.142658 ]
#   [  -6.9355416]
#   [ 380.4699   ]
#   [  72.58723  ]
#   [-149.61284  ]
#   [ -20.993525 ]
#   [  52.294327 ]
#   [ -67.949615 ]
#   [ 137.33987  ]
#   [  55.42716  ]
#   [ -59.15956  ]
#   [-157.811    ]
#   [  59.74205  ]
#   [ 235.55376  ]
#   [ -81.72519  ]
#   [ 209.07878  ]
#   [-330.92133  ]]]
# 24 [" new change right over screen at want right show there’s plan a working 1 michelle one state than make there 2021 what grateful away breathe just vote tested happy new like let's you got four wanted available his send us this of historic so were on work an lives people change role change other drop shaped stake"]
# d_loss 0.6911270916461945
# d_acc: 0.5757575631141663
# g_loss [0.6842473745346069, 0.27272728085517883]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 118.77291  ]
#   [ -76.977264 ]
#   [ -35.86807  ]
#   [-166.16551  ]
#   [ 476.87344  ]
#   [ -40.91848  ]
#   [ 400.98776  ]
#   [ -49.556522 ]
#   [ 268.56104  ]
#   [ 392.58597  ]
#   [  97.33782  ]
#   [  -3.443093 ]
#   [ 249.40703  ]
#   [ 202.20766  ]
#   [ 115.88215  ]
#   [ -47.819424 ]
#   [ 298.7026   ]
#   [ 160.35147  ]
#   [ -21.69847  ]
#   [ 102.80285  ]
#   [ 181.0956   ]
#   [ -88.4115   ]
#   [ 368.01492  ]
#   [ 318.51453  ]
#   [ 439.74136  ]
#   [ 219.26003  ]
#   [  16.786463 ]
#   [-315.4454   ]
#   [ 197.93358  ]
#   [-127.75515  ]
#   [ -65.59347  ]
#   [ 206.22018  ]
#   [  -8.716336 ]
#   [-162.1296   ]
#   [ 195.17935  ]
#   [ 453.05756  ]
#   [ 248.01888  ]
#   [  70.611725 ]
#   [ 276.4633   ]
#   [ -41.77352  ]
#   [  -9.5116825]
#   [  -8.623842 ]
#   [ 440.44717  ]
#   [  83.64145  ]
#   [-174.45952  ]
#   [ -24.559492 ]
#   [  59.787518 ]
#   [ -80.11241  ]
#   [ 159.88747  ]
#   [  64.166016 ]
#   [ -67.86569  ]
#   [-182.73384  ]
#   [  70.150696 ]
#   [ 272.92877  ]
#   [ -95.05966  ]
#   [ 242.8685   ]
#   [-383.8406   ]]]
# 25 [' had what but s blessing out aimed by respond dropped who and anyone under down how then way my things box covid helpless trying rejoining presidential your service upcoming voter ballot protecting you build protect enter congratulations could together get this you paris plan protection can change love book democracy an issues could ways any lead jobs']
# d_loss 0.6900741755962372
# d_acc: 0.5
# g_loss [0.6737650632858276, 0.39393940567970276]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 0.00140119]
#   [-0.00791151]
#   [ 0.00519638]
#   [-0.00899333]
#   [ 0.04389331]
#   [ 0.00601037]
#   [ 0.05599426]
#   [ 0.0060224 ]
#   [ 0.03935219]
#   [ 0.05182466]
#   [ 0.02243508]
#   [ 0.00836463]
#   [ 0.03740735]
#   [ 0.03630701]
#   [ 0.02710529]
#   [-0.00120869]
#   [ 0.0426769 ]
#   [ 0.02492492]
#   [ 0.00923984]
#   [ 0.01471414]
#   [ 0.02149214]
#   [ 0.00139871]
#   [ 0.05016563]
#   [ 0.03839138]
#   [ 0.04985616]
#   [ 0.02899815]
#   [ 0.01588458]
#   [-0.0195727 ]
#   [ 0.01739983]
#   [-0.0136705 ]
#   [ 0.01162576]
#   [ 0.03468511]
#   [-0.01105487]
#   [ 0.00378584]
#   [ 0.04040021]
#   [ 0.05853377]
#   [ 0.03758761]
#   [ 0.00698991]
#   [ 0.03676401]
#   [-0.00148019]
#   [-0.00942533]
#   [-0.00625533]
#   [ 0.05276211]
#   [ 0.01577446]
#   [-0.02112362]
#   [-0.00094661]
#   [ 0.01066722]
#   [-0.02028799]
#   [ 0.01723384]
#   [-0.00765197]
#   [-0.02640162]
#   [-0.03774508]
#   [-0.00320913]
#   [ 0.02747348]
#   [-0.03262626]
#   [ 0.00324651]
#   [-0.05581264]]]
# 26 ['']
# d_loss 0.6829195022583008
# d_acc: 0.4848484843969345
# g_loss [0.6910713315010071, 0.3333333432674408]
# (1, 57, 1)
# (1, 57, 1)
# [[[  60.528515 ]
#   [ -51.158024 ]
#   [  -8.480851 ]
#   [-105.99968  ]
#   [ 268.39     ]
#   [ -33.38498  ]
#   [ 240.56517  ]
#   [ -35.231422 ]
#   [ 162.1584   ]
#   [ 235.72588  ]
#   [  59.1893   ]
#   [  -9.637986 ]
#   [ 144.40096  ]
#   [ 116.96663  ]
#   [  64.18709  ]
#   [ -36.04424  ]
#   [ 178.38927  ]
#   [  96.98392  ]
#   [ -10.565887 ]
#   [  59.859966 ]
#   [ 108.48872  ]
#   [ -50.284904 ]
#   [ 215.85406  ]
#   [ 184.83298  ]
#   [ 257.9204   ]
#   [ 126.54225  ]
#   [  10.538128 ]
#   [-184.0531   ]
#   [ 116.16541  ]
#   [ -74.87789  ]
#   [ -39.057858 ]
#   [ 118.483406 ]
#   [  -3.7319207]
#   [ -91.081314 ]
#   [ 113.13555  ]
#   [ 264.1288   ]
#   [ 143.47865  ]
#   [  41.573193 ]
#   [ 161.80359  ]
#   [ -26.605186 ]
#   [  -3.909336 ]
#   [  -2.1330867]
#   [ 256.2912   ]
#   [  50.453262 ]
#   [-102.231636 ]
#   [ -17.617853 ]
#   [  34.307125 ]
#   [ -49.414394 ]
#   [  93.749084 ]
#   [  35.89962  ]
#   [ -41.502506 ]
#   [-106.589386 ]
#   [  40.61632  ]
#   [ 159.75145  ]
#   [ -54.812016 ]
#   [ 142.2109   ]
#   [-224.11926  ]]]
# 27 [' hope year you voting respond one already but build other change this these home democracy us bring few it change keep today isn’t even 888 line it even home me are had and climate take polling control get honor election and the questions today things i have by folks but get michelle out book he back show']
# d_loss 0.6819630861282349
# d_acc: 0.5151515156030655
# g_loss [0.7380123734474182, 0.42424243688583374]
# (1, 57, 1)
# (1, 57, 1)
# [[[  7.310941  ]
#   [ -9.047803  ]
#   [ -3.4926834 ]
#   [-17.223866  ]
#   [ 40.538967  ]
#   [ -4.155059  ]
#   [ 40.549664  ]
#   [ -4.9871225 ]
#   [ 26.410467  ]
#   [ 35.388718  ]
#   [  9.9896    ]
#   [ -2.8520732 ]
#   [ 20.940804  ]
#   [ 19.446438  ]
#   [  7.4786186 ]
#   [ -7.596551  ]
#   [ 29.262295  ]
#   [ 13.660948  ]
#   [ -0.9651148 ]
#   [  9.812647  ]
#   [ 16.172447  ]
#   [ -7.636409  ]
#   [ 34.977837  ]
#   [ 30.119825  ]
#   [ 39.44873   ]
#   [ 21.368204  ]
#   [  2.1796389 ]
#   [-28.121077  ]
#   [ 17.82057   ]
#   [-12.161437  ]
#   [ -6.0429254 ]
#   [ 20.641256  ]
#   [ -1.9170018 ]
#   [-14.925274  ]
#   [ 17.476688  ]
#   [ 42.32462   ]
#   [ 23.33279   ]
#   [  7.6673403 ]
#   [ 24.002277  ]
#   [ -3.6631734 ]
#   [ -0.08025441]
#   [ -3.34127   ]
#   [ 41.483982  ]
#   [  7.4726872 ]
#   [-15.010692  ]
#   [ -0.8854845 ]
#   [  6.108165  ]
#   [ -7.2665563 ]
#   [ 13.156539  ]
#   [  7.0869617 ]
#   [ -7.050432  ]
#   [-17.99175   ]
#   [  6.6887236 ]
#   [ 26.410769  ]
#   [ -8.414639  ]
#   [ 21.981241  ]
#   [-36.412216  ]]]
# 28 [' our this and i out a out a election but this the on make our our was vote this your our have from are my the at i is of on to all i day with our can and and get our that of our vote our our i of election you my us']
# d_loss 0.6877168416976929
# d_acc: 0.5757575929164886
# g_loss [0.7297995686531067, 0.3030303120613098]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 0.3818032 ]
#   [-0.81301093]
#   [-0.54739153]
#   [-1.4317548 ]
#   [ 3.355581  ]
#   [-0.3357451 ]
#   [ 3.6730077 ]
#   [-0.25248167]
#   [ 2.5323088 ]
#   [ 2.8994946 ]
#   [ 0.73184854]
#   [-0.41274995]
#   [ 1.5234553 ]
#   [ 1.6477216 ]
#   [ 0.38755044]
#   [-0.6519109 ]
#   [ 2.686172  ]
#   [ 0.90128744]
#   [-0.14279252]
#   [ 0.9730285 ]
#   [ 1.2425121 ]
#   [-0.58836687]
#   [ 2.8873117 ]
#   [ 2.658645  ]
#   [ 3.2875757 ]
#   [ 1.8847761 ]
#   [ 0.19363227]
#   [-2.2021627 ]
#   [ 1.4179091 ]
#   [-0.944348  ]
#   [-0.5144397 ]
#   [ 1.9350489 ]
#   [-0.32911858]
#   [-1.509736  ]
#   [ 1.5778756 ]
#   [ 3.6552668 ]
#   [ 2.020527  ]
#   [ 0.6957913 ]
#   [ 1.9898015 ]
#   [-0.22141045]
#   [-0.15154546]
#   [-0.5514723 ]
#   [ 3.5780795 ]
#   [ 0.52380383]
#   [-1.0960531 ]
#   [ 0.20563634]
#   [ 0.60005593]
#   [-0.47857216]
#   [ 1.0410255 ]
#   [ 0.7124802 ]
#   [-0.52824545]
#   [-1.5739568 ]
#   [ 0.50376475]
#   [ 2.2068353 ]
#   [-0.7246511 ]
#   [ 1.7097902 ]
#   [-3.0747368 ]]]
# 29 [' to and and the the to to the to the the and to the to to to to and the to and to to to the to and']
# d_loss 0.6878039538860321
# d_acc: 0.4848484992980957
# g_loss [0.6725097894668579, 0.27272728085517883]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 1.4939411 ]
#   [-1.4192643 ]
#   [-0.13604203]
#   [-2.6859431 ]
#   [ 3.1255047 ]
#   [-0.08385193]
#   [ 3.7469678 ]
#   [-0.56347114]
#   [ 2.437946  ]
#   [ 2.8725722 ]
#   [ 0.46902725]
#   [ 0.17437503]
#   [ 2.2171345 ]
#   [ 0.59733886]
#   [ 0.43494725]
#   [-1.5219418 ]
#   [ 1.7818142 ]
#   [ 1.9148865 ]
#   [ 0.14346434]
#   [ 0.76712626]
#   [ 1.0256778 ]
#   [-1.4421142 ]
#   [ 3.667815  ]
#   [ 2.3630714 ]
#   [ 2.3968775 ]
#   [ 2.528458  ]
#   [ 0.13449219]
#   [-3.4263346 ]
#   [ 2.0962284 ]
#   [-1.4425371 ]
#   [ 0.8043263 ]
#   [ 2.2490897 ]
#   [ 0.9479767 ]
#   [-1.1186838 ]
#   [ 1.5789783 ]
#   [ 3.3967845 ]
#   [ 3.4626071 ]
#   [-0.19733934]
#   [ 1.9250976 ]
#   [ 0.0805531 ]
#   [ 0.28433272]
#   [-0.90950614]
#   [ 3.2741454 ]
#   [ 0.03558328]
#   [-2.3211703 ]
#   [-0.44286454]
#   [-0.04866281]
#   [-0.56517756]
#   [ 2.019905  ]
#   [ 0.5623445 ]
#   [-0.16602004]
#   [-1.7233149 ]
#   [ 1.6013988 ]
#   [ 2.5139303 ]
#   [-1.3844332 ]
#   [ 2.2567883 ]
#   [-3.182405  ]]]
# 30 [' to to the and and the the the to to to to to and the the the and the to the to to and and to and the the to to the to the and']
# d_loss 0.7324669361114502
# d_acc: 0.4848484992980957
# g_loss [0.6869298219680786, 0.27272728085517883]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 0.26701355]
#   [-0.6624992 ]
#   [-0.30063444]
#   [-1.1560092 ]
#   [ 2.4280252 ]
#   [-0.33872488]
#   [ 2.762394  ]
#   [-0.20518364]
#   [ 1.8997725 ]
#   [ 2.2025306 ]
#   [ 0.52389264]
#   [-0.33271778]
#   [ 1.1581523 ]
#   [ 1.194152  ]
#   [ 0.28070632]
#   [-0.5679573 ]
#   [ 1.9924151 ]
#   [ 0.74126375]
#   [-0.08089508]
#   [ 0.70299625]
#   [ 0.93555224]
#   [-0.44933143]
#   [ 2.1744242 ]
#   [ 1.9567293 ]
#   [ 2.4254174 ]
#   [ 1.4023536 ]
#   [ 0.15188459]
#   [-1.6713194 ]
#   [ 1.0761231 ]
#   [-0.7322012 ]
#   [-0.34052575]
#   [ 1.4223597 ]
#   [-0.19839829]
#   [-1.065389  ]
#   [ 1.1627817 ]
#   [ 2.6892142 ]
#   [ 1.5310804 ]
#   [ 0.49291164]
#   [ 1.4825177 ]
#   [-0.16120243]
#   [-0.07823592]
#   [-0.3762923 ]
#   [ 2.630931  ]
#   [ 0.39081264]
#   [-0.8559716 ]
#   [ 0.10365013]
#   [ 0.4139016 ]
#   [-0.3894532 ]
#   [ 0.80196035]
#   [ 0.5025122 ]
#   [-0.398826  ]
#   [-1.1751406 ]
#   [ 0.40465268]
#   [ 1.6418656 ]
#   [-0.55718064]
#   [ 1.2896576 ]
#   [-2.287471  ]]]
# 31 [' to the the to the to to to the to the to to to to to to the to to the to to to the']
# d_loss 0.6796913146972656
# d_acc: 0.4848484843969345
# g_loss [0.7271019220352173, 0.24242424964904785]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 0.09200001]
#   [-0.19580412]
#   [-0.02250765]
#   [-0.35192722]
#   [ 0.70642364]
#   [-0.11315989]
#   [ 0.78876144]
#   [-0.07118734]
#   [ 0.521118  ]
#   [ 0.6777027 ]
#   [ 0.18066886]
#   [-0.07698216]
#   [ 0.38745946]
#   [ 0.3626959 ]
#   [ 0.13518193]
#   [-0.17982759]
#   [ 0.56142175]
#   [ 0.27982244]
#   [-0.00373804]
#   [ 0.17651078]
#   [ 0.2965202 ]
#   [-0.12740828]
#   [ 0.6588203 ]
#   [ 0.55589116]
#   [ 0.71926224]
#   [ 0.39686453]
#   [ 0.06133397]
#   [-0.5048438 ]
#   [ 0.32561162]
#   [-0.23886392]
#   [-0.08273882]
#   [ 0.39218992]
#   [-0.03395652]
#   [-0.24001762]
#   [ 0.33324045]
#   [ 0.77158827]
#   [ 0.4457568 ]
#   [ 0.14290008]
#   [ 0.44870827]
#   [-0.05771208]
#   [-0.00372503]
#   [-0.04997601]
#   [ 0.7496247 ]
#   [ 0.13469945]
#   [-0.27650645]
#   [-0.01842521]
#   [ 0.09800122]
#   [-0.15312642]
#   [ 0.24685799]
#   [ 0.11064215]
#   [-0.14487164]
#   [-0.35951695]
#   [ 0.12641902]
#   [ 0.4764559 ]
#   [-0.18050253]
#   [ 0.38412407]
#   [-0.67314017]]]
# 32 ['']
# d_loss 0.7238547801971436
# d_acc: 0.5000000149011612
# g_loss [0.7131850719451904, 0.12121212482452393]
# (1, 57, 1)
# (1, 57, 1)
# [[[  6.7540655 ]
#   [ -3.2817483 ]
#   [  5.852311  ]
#   [ -0.02248091]
#   [ -1.1880002 ]
#   [  3.3035476 ]
#   [ -4.376328  ]
#   [ -0.8192665 ]
#   [-10.202846  ]
#   [ -3.5924952 ]
#   [  2.4953644 ]
#   [  0.68150014]
#   [  5.182256  ]
#   [ -2.57272   ]
#   [ -0.3685241 ]
#   [ -6.4000564 ]
#   [ -4.724954  ]
#   [  7.3405943 ]
#   [  2.7247    ]
#   [ -5.1210055 ]
#   [  0.14455593]
#   [ -3.656882  ]
#   [  2.7550142 ]
#   [ -3.7284682 ]
#   [ -7.2151    ]
#   [ -0.68106014]
#   [  1.6675373 ]
#   [ -5.1351056 ]
#   [  0.58258384]
#   [ -4.8302197 ]
#   [  6.668236  ]
#   [ -1.9319781 ]
#   [  3.746567  ]
#   [  5.7450905 ]
#   [ -1.4920526 ]
#   [ -7.6208396 ]
#   [  2.326893  ]
#   [ -2.4690375 ]
#   [ -1.6181793 ]
#   [  5.301201  ]
#   [  5.6935205 ]
#   [  5.6743073 ]
#   [-10.094905  ]
#   [ -3.1785507 ]
#   [ -5.4439664 ]
#   [ -6.1686134 ]
#   [ -5.425635  ]
#   [  0.07634857]
#   [  1.3683149 ]
#   [ -2.327892  ]
#   [  4.2526054 ]
#   [  1.590832  ]
#   [  4.31088   ]
#   [ -5.194896  ]
#   [ -0.33770984]
#   [  4.334065  ]
#   [ -0.41663423]]]
# 33 [' of and in to and a it and the in the of a our the in and the and our to in a of to and in to our the the to in in in it and in of in to the a to a in a']
# d_loss 0.6800620257854462
# d_acc: 0.530303031206131
# g_loss [0.7106761336326599, 0.12121212482452393]
# (1, 57, 1)
# (1, 57, 1)
# [[[  30.143925 ]
#   [ -50.896748 ]
#   [   9.861815 ]
#   [ -96.664795 ]
#   [ 191.0017   ]
#   [ -51.29914  ]
#   [ 200.5009   ]
#   [ -27.017782 ]
#   [ 141.99062  ]
#   [ 193.88208  ]
#   [  37.274822 ]
#   [ -22.535452 ]
#   [ 104.17638  ]
#   [  87.021034 ]
#   [  40.53512  ]
#   [ -40.264812 ]
#   [ 147.68388  ]
#   [  75.980934 ]
#   [  -8.164419 ]
#   [  49.359528 ]
#   [  84.124916 ]
#   [ -36.76061  ]
#   [ 165.31326  ]
#   [ 143.33582  ]
#   [ 200.73132  ]
#   [  95.26866  ]
#   [   9.131356 ]
#   [-139.32753  ]
#   [  89.30554  ]
#   [ -57.290363 ]
#   [ -30.60067  ]
#   [  89.4259   ]
#   [  -0.6838052]
#   [ -68.96249  ]
#   [  85.37833  ]
#   [ 201.41371  ]
#   [ 107.00799  ]
#   [  32.13301  ]
#   [ 126.44833  ]
#   [ -22.108664 ]
#   [  -6.828561 ]
#   [   0.6858361]
#   [ 196.16605  ]
#   [  37.66889  ]
#   [ -76.68307  ]
#   [ -13.63499  ]
#   [  26.658386 ]
#   [ -40.038136 ]
#   [  72.72555  ]
#   [  27.06081  ]
#   [ -32.241905 ]
#   [ -82.218994 ]
#   [  32.34959  ]
#   [ 121.77424  ]
#   [ -43.78987  ]
#   [ 109.67477  ]
#   [-169.57053  ]]]
# 34 [' from today this few getting year big country last workers will as pandemic there out out white not you by better us u control big any this land save early from save joe those join proud or line as of register will what vote election out so country or some or best georgia new poll']
# d_loss 0.6890901029109955
# d_acc: 0.5151515305042267
# g_loss [0.7286946177482605, 0.27272728085517883]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 3.34027405e+01]
#   [-5.94649506e+01]
#   [ 1.37550278e+01]
#   [-1.12455208e+02]
#   [ 2.17867599e+02]
#   [-6.23536758e+01]
#   [ 2.31270004e+02]
#   [-3.09280510e+01]
#   [ 1.64955978e+02]
#   [ 2.24578400e+02]
#   [ 4.13376579e+01]
#   [-2.74144192e+01]
#   [ 1.18957321e+02]
#   [ 9.92343369e+01]
#   [ 4.61976395e+01]
#   [-4.72554665e+01]
#   [ 1.70237183e+02]
#   [ 8.77851181e+01]
#   [-9.64515018e+00]
#   [ 5.68037720e+01]
#   [ 9.66921463e+01]
#   [-4.22736855e+01]
#   [ 1.89273773e+02]
#   [ 1.64483414e+02]
#   [ 2.30956131e+02]
#   [ 1.08647385e+02]
#   [ 1.06225405e+01]
#   [-1.59753159e+02]
#   [ 1.02712692e+02]
#   [-6.55895767e+01]
#   [-3.51875916e+01]
#   [ 1.01951805e+02]
#   [ 1.47480428e-01]
#   [-7.88712234e+01]
#   [ 9.74964066e+01]
#   [ 2.30187134e+02]
#   [ 1.21865189e+02]
#   [ 3.64475098e+01]
#   [ 1.45809784e+02]
#   [-2.55259132e+01]
#   [-8.78573322e+00]
#   [ 2.11962557e+00]
#   [ 2.24570282e+02]
#   [ 4.30235558e+01]
#   [-8.78615265e+01]
#   [-1.62343636e+01]
#   [ 3.04261742e+01]
#   [-4.62991753e+01]
#   [ 8.39475021e+01]
#   [ 3.07879658e+01]
#   [-3.69621353e+01]
#   [-9.41140823e+01]
#   [ 3.75987663e+01]
#   [ 1.39335327e+02]
#   [-5.09839287e+01]
#   [ 1.26188408e+02]
#   [-1.93720596e+02]]]
# 35 [" one change vote across working years baseball from i’ve show get country had you're time how happy there this because few day week i’ve faced keep it book things ballot but most president who faced best us health if you the show georgia there your from time plan from us world will land today line workers"]
# d_loss 0.6808924078941345
# d_acc: 0.5
# g_loss [0.7295923829078674, 0.4848484992980957]
# (1, 57, 1)
# (1, 57, 1)
# [[[  38.911564 ]
#   [ -72.45144  ]
#   [  19.295559 ]
#   [-136.70392  ]
#   [ 260.34283  ]
#   [ -78.872925 ]
#   [ 279.0108   ]
#   [ -37.058414 ]
#   [ 200.42192  ]
#   [ 272.32184  ]
#   [  47.990135 ]
#   [ -34.632214 ]
# ...
#   [ -62.11243 ]
#   [ 134.06987 ]
#   [-214.96501 ]]]
# 87 [' there it few should part us safely down last remember time with let’s my do these run no like four lot because blessings best workers because them already power land election way like sure any run poll today protection like if could birthday plan right it we life proud at from pandemic work build years over feeling']
# d_loss 0.7238089144229889
# d_acc: 0.7272727191448212
# g_loss [0.670376718044281, 0.3636363744735718]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 18.766047  ]
#   [-15.185707  ]
#   [-25.347878  ]
#   [ -5.2818027 ]
#   [  4.361106  ]
#   [ 12.276783  ]
#   [-39.383373  ]
#   [  7.8095465 ]
#   [-25.896599  ]
#   [  7.9735293 ]
#   [ -2.5885293 ]
#   [ -3.2578335 ]
#   [ 38.066822  ]
#   [-25.344604  ]
#   [ 29.277914  ]
#   [ 26.912106  ]
#   [  2.212615  ]
#   [ 31.940334  ]
#   [ 31.467487  ]
#   [-29.560738  ]
#   [ 28.734106  ]
#   [-30.317884  ]
#   [-23.322834  ]
#   [ 11.904718  ]
#   [-18.249853  ]
#   [-16.326345  ]
#   [ -3.8317552 ]
#   [  9.214992  ]
#   [-21.248154  ]
#   [ -7.7588763 ]
#   [-16.523891  ]
#   [-10.655265  ]
#   [-17.146332  ]
#   [ -5.43858   ]
#   [  3.0547235 ]
#   [  9.169523  ]
#   [ -0.90174323]
#   [ -4.931173  ]
#   [ 14.965112  ]
#   [ 21.661112  ]
#   [ 18.969505  ]
#   [ -5.29708   ]
#   [-31.633228  ]
#   [-21.201727  ]
#   [ 20.190136  ]
#   [  1.8550094 ]
#   [ -2.1443868 ]
#   [ -1.2824961 ]
#   [-11.522522  ]
#   [ -1.9673439 ]
#   [ 16.553164  ]
#   [ 12.251896  ]
#   [-24.189539  ]
#   [-28.034534  ]
#   [-21.16535   ]
#   [  9.238766  ]
#   [  3.2891266 ]]]
# 88 [' we that if in a is are our if our the and right if was election the do do was at from with for we your and this my our your it i in and this a all my we in do my on to the to for to your is can at my this and']
# d_loss 0.7340138256549835
# d_acc: 0.45454545319080353
# g_loss [0.6802830696105957, 0.42424243688583374]
# (1, 57, 1)
# (1, 57, 1)
# [[[ -9.434633  ]
#   [-13.580651  ]
#   [ -0.31232828]
#   [  3.6813443 ]
#   [-36.380196  ]
#   [ 46.154556  ]
#   [-63.708214  ]
#   [ 10.937653  ]
#   [-73.04886   ]
#   [-30.862326  ]
#   [ 75.554016  ]
#   [-36.131023  ]
#   [  5.5736194 ]
#   [ 37.80759   ]
#   [  0.97993386]
#   [-15.390858  ]
#   [  2.0236323 ]
#   [ 32.91972   ]
#   [ 44.05573   ]
#   [-61.26271   ]
#   [-21.33764   ]
#   [ -0.17075562]
#   [-26.691727  ]
#   [  2.8003857 ]
#   [ 27.073631  ]
#   [-70.634445  ]
#   [  4.229685  ]
#   [ 40.922504  ]
#   [-60.441853  ]
#   [-19.59338   ]
#   [ -2.3732898 ]
#   [-40.407288  ]
#   [-35.546703  ]
#   [ 65.09858   ]
#   [ 34.79583   ]
#   [-36.67332   ]
#   [ 31.241098  ]
#   [  4.617052  ]
#   [ 94.678215  ]
#   [ 38.717236  ]
#   [ 67.40934   ]
#   [-11.437965  ]
#   [-27.382034  ]
#   [-31.317383  ]
#   [ 44.368134  ]
#   [ -2.8721874 ]
#   [ 39.503967  ]
#   [  9.395437  ]
#   [ 17.39949   ]
#   [  6.219236  ]
#   [ -2.477117  ]
#   [ 47.45306   ]
#   [ -8.621689  ]
#   [ 31.250254  ]
#   [  9.368104  ]
#   [ 35.36952   ]
#   [-58.91376   ]]]
# 89 [' this vote and us time before it only from not us in will that the or them his my election the country could a out hope make the out but ballot have us do a world right an for country do them the are this i of the how you do this but like']
# d_loss 0.6840071380138397
# d_acc: 0.37878789007663727
# g_loss [0.7444953322410583, 0.8787878751754761]
# (1, 57, 1)
# (1, 57, 1)
# [[[  66.66904 ]
#   [  -6.717264]
#   [  73.005226]
#   [-160.44562 ]
#   [ 225.97447 ]
#   [ -24.781971]
#   [ 263.33243 ]
#   [ -88.40654 ]
#   [ 106.0569  ]
#   [ 254.19984 ]
#   [ -35.996674]
#   [  19.13291 ]
#   [  51.83997 ]
#   [  15.035783]
#   [ -27.269049]
#   [-110.81146 ]
#   [ 201.57906 ]
#   [ 131.05072 ]
#   [  45.83479 ]
#   [ 129.2427  ]
#   [  50.415928]
#   [  44.98061 ]
#   [ 214.15276 ]
#   [  90.77811 ]
#   [ 143.81819 ]
#   [  42.025322]
#   [ -35.689808]
#   [-183.53508 ]
#   [ 139.43237 ]
#   [-106.94918 ]
#   [  21.336264]
#   [ 123.62321 ]
#   [ -47.47705 ]
#   [-102.979576]
#   [  73.19712 ]
#   [ 201.30391 ]
#   [ 130.25232 ]
#   [  39.62829 ]
#   [ 131.31444 ]
#   [ -44.774635]
#   [ -17.882557]
#   [  52.599503]
#   [ 177.29706 ]
#   [  63.98836 ]
#   [ -27.63042 ]
#   [  -6.635753]
#   [  13.812266]
#   [ -68.83035 ]
#   [  80.16384 ]
#   [  21.843157]
#   [ -22.775717]
#   [ -79.15271 ]
#   [  39.038258]
#   [ 123.37916 ]
#   [ -45.777454]
#   [ 100.69136 ]
#   [-163.7529  ]]]
# 90 [" about of only way surprise can run covid michelle matter but make year that country into join has be it’s today them feeling life control day but power land michelle my everyone how things only join americans are has them i work let's before country of vote joe love my as now are everyone be help she"]
# d_loss 0.7175877094268799
# d_acc: 0.4848484992980957
# g_loss [0.7394208312034607, 0.9090909361839294]
# (1, 57, 1)
# (1, 57, 1)
# [[[ -1.9274961 ]
#   [  7.742633  ]
#   [ -3.413744  ]
#   [  7.843507  ]
#   [  0.59921145]
#   [ 10.7764225 ]
#   [-21.223347  ]
#   [  2.6336513 ]
#   [ -2.8144624 ]
#   [ -9.383133  ]
#   [ -0.89266247]
#   [  8.605763  ]
#   [  5.7512093 ]
#   [ -8.38207   ]
#   [  7.088547  ]
#   [ -2.261703  ]
#   [ -7.4804873 ]
#   [  2.0264394 ]
#   [  8.4371605 ]
#   [-10.133301  ]
#   [  5.064399  ]
#   [ -6.863412  ]
#   [  6.1367416 ]
#   [ -4.926503  ]
#   [ -6.458694  ]
#   [  3.4612548 ]
#   [  3.6216903 ]
#   [  8.059545  ]
#   [ -6.9083176 ]
#   [  2.657388  ]
#   [ -2.204471  ]
#   [ -7.1952124 ]
#   [  7.006089  ]
#   [ 23.14322   ]
#   [ -9.54112   ]
#   [-12.716993  ]
#   [ -8.150685  ]
#   [-11.332856  ]
#   [-11.756703  ]
#   [ 13.587848  ]
#   [  2.543028  ]
#   [  5.6255116 ]
#   [ -7.5705924 ]
#   [ -9.0795    ]
#   [ -0.7578534 ]
#   [  7.5566483 ]
#   [ -5.817864  ]
#   [ -2.8915265 ]
#   [ -5.571508  ]
#   [-18.83135   ]
#   [-15.533368  ]
#   [  9.299754  ]
#   [  7.668322  ]
#   [-10.114773  ]
#   [  2.3560026 ]
#   [  1.9207808 ]
#   [  4.499606  ]]]
# 91 [' to our and our it my the the this you in you our the our the you it in of of a of and and you of the the our our with this is you for for vote the in our this our in the in we that this our it the to a']
# d_loss 0.7141404449939728
# d_acc: 0.5454545617103577
# g_loss [0.6621547937393188, 0.7272727489471436]
# (1, 57, 1)
# (1, 57, 1)
# [[[  -8.53729  ]
#   [  11.400578 ]
#   [  14.219801 ]
#   [  63.545303 ]
#   [ -44.614925 ]
#   [   8.10071  ]
#   [-111.26118  ]
#   [  14.995372 ]
#   [ -67.88789  ]
#   [ -91.1123   ]
#   [  44.991512 ]
#   [  -2.682342 ]
#   [  63.580673 ]
#   [   1.6060414]
#   [  74.00687  ]
#   [  40.128223 ]
#   [ -88.81859  ]
#   [ -20.195879 ]
#   [ -48.649487 ]
#   [-127.05879  ]
#   [  17.700703 ]
#   [ -30.916525 ]
#   [-110.808495 ]
#   [ -80.11006  ]
#   [ -72.78792  ]
#   [  -9.7405815]
#   [  79.95501  ]
#   [  13.40976  ]
#   [ -25.277576 ]
#   [  11.862984 ]
#   [  16.079    ]
#   [ -71.694496 ]
#   [  66.94915  ]
#   [ 122.69511  ]
#   [ -36.233307 ]
#   [-154.16954  ]
#   [ -45.889183 ]
#   [ -17.31642  ]
#   [ -37.415726 ]
#   [  43.088226 ]
#   [  43.00767  ]
#   [  17.841845 ]
#   [ -73.74627  ]
#   [ -37.85656  ]
#   [   5.7618384]
#   [ -80.141846 ]
#   [ -58.59344  ]
#   [  -1.341406 ]
#   [ -16.413134 ]
#   [ -40.905952 ]
#   [ -21.552795 ]
#   [   4.3216667]
#   [  28.899012 ]
#   [ -70.39249  ]
#   [  49.823765 ]
#   [  18.377396 ]
#   [  64.31129  ]]]
# 92 [' you for all before them you communities all an climate them the before to me out covid on we’re voter i from into love so this now vote if for your let’s about we’ve us center be i will georgia georgia i only will in love like to your out my a at could by we democracy']
# d_loss 0.7417789399623871
# d_acc: 0.6363636553287506
# g_loss [0.6544398069381714, 0.5454545617103577]
# (1, 57, 1)
# (1, 57, 1)
# [[[   4.93274   ]
#   [  -1.273593  ]
#   [  -5.3440504 ]
#   [  31.6199    ]
#   [-164.1773    ]
#   [  -1.4520214 ]
#   [-288.66974   ]
#   [  31.842379  ]
#   [-143.9605    ]
#   [-221.0831    ]
#   [  19.475674  ]
#   [ -11.986173  ]
#   [  43.886375  ]
#   [ -32.359432  ]
#   [ 120.74097   ]
#   [  30.663048  ]
#   [-274.6066    ]
#   [  34.74107   ]
#   [ -59.93365   ]
#   [-209.8201    ]
#   [ -56.310535  ]
#   [ -57.67435   ]
#   [-216.42702   ]
#   [-210.96439   ]
#   [-176.27792   ]
#   [ -34.09028   ]
#   [  66.51986   ]
#   [  43.65166   ]
#   [ -63.051556  ]
#   [  15.242232  ]
#   [ 118.27023   ]
#   [ -97.6219    ]
#   [ 175.5581    ]
#   [ 229.86577   ]
#   [ -47.569458  ]
#   [-329.90686   ]
#   [  -8.473172  ]
#   [-101.572716  ]
#   [ -55.279076  ]
#   [  47.91592   ]
#   [ 139.10844   ]
#   [   5.6540904 ]
#   [-169.5397    ]
#   [-118.95851   ]
#   [ -38.01729   ]
#   [-131.49817   ]
#   [ -35.789043  ]
#   [   0.79057413]
#   [  30.427006  ]
#   [ -93.17277   ]
#   [ -12.11335   ]
#   [  56.73892   ]
#   [  41.541973  ]
#   [-105.34985   ]
#   [  36.27518   ]
#   [ -29.063     ]
#   [ 122.56732   ]]]
# 93 [' a to in do i’ve to cases do control much make for georgia or ever from away have change shaped because early long should 1 have about georgia before that had who hotline robinson how depends you most people how land in poll had right has but from folks is because get voting us was we’ve']
# d_loss 0.7125732898712158
# d_acc: 0.42424243688583374
# g_loss [0.7099587321281433, 0.8484848737716675]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 173.40836 ]
#   [ -45.047337]
#   [ 126.31899 ]
#   [-538.8583  ]
#   [ 741.90967 ]
#   [  -9.239474]
#   [1002.2816  ]
#   [-262.8053  ]
#   [ 395.37952 ]
#   [ 769.33215 ]
#   [-120.045784]
#   [  34.237175]
#   [  96.25437 ]
#   [  66.1091  ]
#   [-228.61626 ]
#   [-418.822   ]
#   [ 761.6029  ]
#   [ 348.03198 ]
#   [ 178.54066 ]
#   [ 482.81357 ]
#   [ 117.24221 ]
#   [ 174.23755 ]
#   [ 745.8328  ]
#   [ 346.4489  ]
#   [ 424.40286 ]
#   [ 197.66055 ]
#   [-130.01312 ]
#   [-593.28827 ]
#   [ 454.0613  ]
#   [-367.7445  ]
#   [  89.27451 ]
#   [ 523.79846 ]
#   [-258.7696  ]
#   [-437.38956 ]
#   [ 267.78976 ]
#   [ 743.6564  ]
#   [ 512.893   ]
#   [ 166.8081  ]
#   [ 379.49365 ]
#   [-117.62411 ]
#   [ -41.69207 ]
#   [  19.616571]
#   [ 657.4917  ]
#   [ 209.18478 ]
#   [ -51.866398]
#   [  85.66385 ]
#   [  81.73496 ]
#   [-192.48117 ]
#   [ 213.33537 ]
#   [ 146.31128 ]
#   [ -57.512543]
#   [-292.49512 ]
#   [ 114.570724]
#   [ 457.16788 ]
#   [-129.05339 ]
#   [ 303.1765  ]
#   [-609.0243  ]]]
# 94 [" call be line evicted lady this voice club doing ever have few about jackie screen candidates––and display bring beloved off protection path labor 96 upcoming americans actions question threat save action 730 example go coronavirus here's s breathe off get make chance shaped year those drop important real during early stuck look redeeming it’s mask listening"]
# d_loss 0.710790753364563
# d_acc: 0.4696969836950302
# g_loss [0.7546302080154419, 0.9090909361839294]
# (1, 57, 1)
# (1, 57, 1)
# [[[  3.0264075 ]
#   [  0.80750954]
#   [  2.8621104 ]
#   [  2.8777552 ]
#   [ -5.136748  ]
#   [ -0.425384  ]
#   [-12.303776  ]
#   [ -1.5753702 ]
#   [ -6.002052  ]
#   [ -5.575568  ]
#   [  2.4097557 ]
#   [  3.4838116 ]
#   [  3.2928774 ]
#   [  0.2777009 ]
#   [  9.106919  ]
#   [  0.8421339 ]
#   [ -9.0215645 ]
#   [ -0.94113064]
#   [ -1.0599642 ]
#   [ -7.408761  ]
#   [  1.8757935 ]
#   [ -0.64148265]
#   [ -2.762629  ]
#   [ -3.7379942 ]
#   [ -3.901923  ]
#   [  0.4629338 ]
#   [  1.503228  ]
#   [  0.03319585]
#   [  0.96655613]
#   [  3.1423352 ]
#   [ -3.2763245 ]
#   [ -6.8924065 ]
#   [  5.0333977 ]
#   [ 13.727689  ]
#   [ -3.6429052 ]
#   [ -9.751954  ]
#   [ -2.023754  ]
#   [ -2.8533294 ]
#   [ -8.074714  ]
#   [  1.9332318 ]
#   [  3.329944  ]
#   [  2.4859388 ]
#   [ -5.2503533 ]
#   [ -0.7954153 ]
#   [ -2.5222409 ]
#   [ -4.1351113 ]
#   [ -2.2506468 ]
#   [ -2.9915218 ]
#   [ -0.89135516]
#   [ -6.359043  ]
#   [ -3.8965886 ]
#   [  1.1091663 ]
#   [  0.44611016]
#   [ -2.9355664 ]
#   [  4.174419  ]
#   [  0.58270895]
#   [  7.142425  ]]]
# 95 [' and the the in is to of in the and and this this to our to the and and to and and of in vote and this the the you to and the in the a the the of and to the a our']
# d_loss 0.7206036746501923
# d_acc: 0.5151515305042267
# g_loss [0.7054354548454285, 0.8181818127632141]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 1.1772408e+03]
#   [-5.1380566e+02]
#   [-2.2493410e+02]
#   [ 1.5237367e+03]
#   [-6.3847085e+03]
#   [ 9.1980835e+02]
#   [-8.2534521e+03]
#   [ 9.9008569e+02]
#   [-3.6414929e+03]
#   [-6.3004419e+03]
#   [ 5.7640594e+02]
#   [ 1.5994314e+03]
#   [ 1.1618094e+03]
#   [-3.1561199e+03]
#   [ 2.0556042e+03]
#   [ 6.3541675e+02]
#   [-8.3460469e+03]
#   [ 2.4964677e+02]
#   [-5.4118872e+02]
#   [-4.2285034e+03]
#   [-1.5574398e+03]
#   [-2.6566003e+03]
#   [-4.3067842e+03]
#   [-4.2658169e+03]
#   [-5.8894097e+03]
#   [-2.2240567e+02]
#   [ 4.8873755e+02]
#   [ 1.7364761e+03]
#   [-1.7384047e+03]
#   [ 1.4744917e+03]
#   [ 2.4622661e+03]
#   [-3.8898857e+03]
#   [ 5.1790703e+03]
#   [ 4.6619673e+03]
#   [-2.4062812e+03]
#   [-6.7692085e+03]
#   [-6.3736379e-01]
#   [-3.1307700e+03]
#   [-3.0989187e+03]
#   [ 1.9918859e+03]
#   [ 2.6635620e+03]
#   [-9.8168073e+02]
#   [-5.6652280e+03]
#   [-2.2765564e+03]
#   [-2.1049932e+03]
#   [-2.2334377e+03]
#   [-1.8141849e+03]
#   [ 9.0411902e+02]
#   [ 1.7692949e+02]
#   [-1.7971017e+03]
#   [ 1.0184286e+03]
#   [ 2.1017332e+03]
#   [ 1.2182111e+03]
#   [-2.4391152e+03]
#   [-2.5879041e+02]
#   [-7.7812921e+02]
#   [ 4.2517310e+03]]]
# 96 [' ringing show also finally anyone eviction black voters 1 730 finishing']
# d_loss 0.7099654078483582
# d_acc: 0.7575757503509521
# g_loss [0.6772976517677307, 0.3333333432674408]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 1380.3942  ]
#   [ -465.9984  ]
#   [  183.09885 ]
#   [ 1180.2156  ]
#   [-5411.8345  ]
#   [  885.9888  ]
#   [-6937.3164  ]
#   [  671.2389  ]
#   [-3540.1934  ]
#   [-5466.796   ]
#   [   32.687897]
#   [  990.0048  ]
#   [  821.12714 ]
#   [-2704.8503  ]
#   [ 1603.1908  ]
#   [  424.24014 ]
#   [-7080.3975  ]
#   [  144.08974 ]
#   [ -593.5186  ]
#   [-3506.2153  ]
#   [-1252.6267  ]
#   [-2631.2627  ]
#   [-3272.864   ]
#   [-3301.1038  ]
#   [-4917.5967  ]
#   [  -34.026615]
#   [  462.64847 ]
#   [ 1396.7892  ]
#   [-1400.9663  ]
#   [ 1255.8385  ]
#   [ 2137.5874  ]
#   [-3226.6025  ]
#   [ 4479.9395  ]
#   [ 3999.3801  ]
#   [-1765.8241  ]
#   [-6157.821   ]
#   [ -317.14642 ]
#   [-2911.0698  ]
#   [-2746.8945  ]
#   [ 1868.2583  ]
#   [ 1892.8147  ]
#   [ -376.29562 ]
#   [-5254.886   ]
#   [-2333.5125  ]
#   [-1980.3745  ]
#   [-2170.5408  ]
#   [-1796.9442  ]
#   [  950.26324 ]
#   [  604.06354 ]
#   [-1622.681   ]
#   [  905.3693  ]
#   [ 1884.4432  ]
#   [ 1390.2592  ]
#   [-2551.1758  ]
#   [ -185.2747  ]
#   [ -959.7149  ]
#   [ 3626.9294  ]]]
# 97 [' clubs power recently or census 96 these actions have jr thank officially tribute you’re']
# d_loss 0.7241148352622986
# d_acc: 0.530303031206131
# g_loss [0.6824076175689697, 0.24242424964904785]
# (1, 57, 1)
# (1, 57, 1)
# [[[  3.83963   ]
#   [ -0.7549472 ]
#   [  2.3911924 ]
#   [  3.6377358 ]
#   [ -6.6907334 ]
#   [  0.13505137]
#   [-12.208044  ]
#   [ -1.4038321 ]
#   [ -8.274137  ]
#   [ -6.0239677 ]
#   [  3.5304513 ]
#   [  3.1495128 ]
#   [  4.2595267 ]
#   [  0.38029385]
#   [  6.330343  ]
#   [ -0.3704329 ]
#   [ -8.017812  ]
#   [ -0.19398017]
#   [  0.8979142 ]
#   [ -7.4250083 ]
#   [  1.8536872 ]
#   [ -2.2483013 ]
#   [ -2.7367833 ]
#   [ -3.4379308 ]
#   [ -3.957951  ]
#   [  0.01677807]
#   [  0.88940173]
#   [  1.3110799 ]
#   [ -2.0451677 ]
#   [  0.2728748 ]
#   [  0.554039  ]
#   [ -8.2276745 ]
#   [  2.7974057 ]
#   [ 10.33892   ]
#   [ -3.9510326 ]
#   [ -8.9895525 ]
#   [ -3.0128512 ]
#   [ -4.033636  ]
#   [ -4.9362173 ]
#   [  0.7730795 ]
#   [  3.3707888 ]
#   [  5.2505407 ]
#   [ -7.872981  ]
#   [  0.46670422]
#   [ -1.766886  ]
#   [ -5.4613214 ]
#   [ -2.5342326 ]
#   [  1.5424294 ]
#   [ -0.8161787 ]
#   [ -3.5501156 ]
#   [  0.35415092]
#   [  2.4564617 ]
#   [  0.75916976]
#   [ -4.284717  ]
#   [  2.3442879 ]
#   [  1.0744797 ]
#   [  4.6453304 ]]]
# 98 [' and the and of is to you of and and a of you our to the the and and to the you the it and you and a a and in our to in the to and the a the to a']
# d_loss 0.6999083161354065
# d_acc: 0.43939393758773804
# g_loss [0.743061900138855, 0.8181818127632141]
# (1, 57, 1)
# (1, 57, 1)
# [[[ 1876.6163 ]
#   [ -830.7042 ]
#   [ -321.5952 ]
#   [ 1092.5381 ]
#   [-6750.814  ]
#   [ 1249.1835 ]
#   [-9596.109  ]
#   [ 1268.5178 ]
#   [-4768.8516 ]
#   [-7121.107  ]
#   [ -163.48972]
#   [ 1247.6854 ]
#   [ 1166.957  ]
#   [-3484.6614 ]
#   [ 2513.0178 ]
#   [  679.10077]
#   [-8992.96   ]
#   [ 1000.9067 ]
#   [ -187.55077]
#   [-5530.5073 ]
#   [-1363.1677 ]
#   [-3549.7026 ]
#   [-4684.1235 ]
#   [-4377.831  ]
#   [-6616.392  ]
#   [ -292.6673 ]
#   [ 1210.3848 ]
#   [ 2032.2528 ]
#   [-2241.17   ]
#   [ 1660.3927 ]
#   [ 2807.9458 ]
#   [-4068.559  ]
#   [ 5143.2544 ]
#   [ 5251.3745 ]
#   [-2239.2065 ]
#   [-7717.0005 ]
#   [ -616.00476]
#   [-4271.069  ]
#   [-3675.2317 ]
#   [ 2466.3257 ]
#   [ 2750.7136 ]
#   [ -212.78117]
#   [-7462.362  ]
#   [-3486.8257 ]
#   [-2367.4485 ]
#   [-2489.212  ]
#   [-2654.3154 ]
#   [ 1476.0417 ]
#   [  537.5378 ]
#   [-2250.3633 ]
#   [ 1129.3146 ]
#   [ 2313.6611 ]
#   [ 1613.7158 ]
#   [-3805.6582 ]
#   [ -281.74487]
#   [-1259.1221 ]
#   [ 4843.229  ]]]
# 99 [' times 100 she decide still stuck school available holidays cherish']
